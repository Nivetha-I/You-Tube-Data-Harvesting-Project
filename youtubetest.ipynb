# %%
#Importing the googleapiclient library and build module

import googleapiclient
from googleapiclient.discovery import build
from pprint import pprint
import pymongo
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi 
import mysql.connector as mysql
import pandas as pd 
import datetime
import isodate
import streamlit as st

# %%
#Creating a function to connect the api service and key throughout the program

def api_connection():
       api_service_name = "youtube"
       api_version = "V3"
       api_key = "AIzaSyBW5i8vq6m3lWELwntKFaOLHBCa9oQqN0w"

       youtube = build(api_service_name,api_version,developerKey=api_key)
       return youtube

# %%
'''Creating a variable called youtube_call and asign the api_connection function to it 
   By assigning that we can call the function whenever we want by  running that variable
'''
youtube_call = api_connection()
#youtube_call

# %%
#Creatint a function called channel_details which contains channel id,name, description,playlist, views and video counts etc..

def get_channel_details(channel_id):
# Requesting the channel to provide CHANNEL DETAILS where it contains parts like id,snippet,startistics,content details

      request = youtube_call.channels().list(
           id = channel_id,
           part = "snippet,statistics,contentDetails"
          )
      response = request.execute()
 #Creating a for loop to access all the  requri
      for i in response["items"]:
        data = dict(
            channel_title = i["snippet"]["title"],
            channel_id= i["id"],
            channel_subscribers = i["statistics"]['subscriberCount'],
            channel_viewcount = i["statistics"]["viewCount"],
            channel_videocount = i["statistics"]["videoCount"],
            channel_description = i["snippet"]["description"],
            channel_playlistid = i["contentDetails"]["relatedPlaylists"]["uploads"]
            )
        
      return data

# %%
'''Creating a variable called channel_detail_call and assigning the channel_detail functions into that variable to call
 whenever we want to use that function
 '''
channel_detail_call =get_channel_details("UCykSoHEAMVSU_w6ACWlxlzA")

# %%
channel_detail_call
# Out:
# {'channel_title': 'Octobit8',
#  'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#  'channel_subscribers': '6',
#  'channel_viewcount': '201',
#  'channel_videocount': '18',
#  'channel_description': '"OctoBit8: Your Tech Partner! Explore DevOps, Cloud, Data Science, Software Dev, IT Outsourcing, Staff Augmentation, and stay ahead in tech. Subscribe now! 💡🚀 #OctoBit8"',
#  'channel_playlistid': 'UUykSoHEAMVSU_w6ACWlxlzA'}

# %%
#Now requesting the youtube to provide PLAYLIST Id from playlists()

def get_video_ids(playlist_ids):
      playlist_request = youtube_call.channels().list(
      part = "contentDetails",
      id = playlist_ids
      )
      playlist_response = playlist_request.execute()
      playlist_id = playlist_response["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

      video_idlist = [] 

      #Creating a variable for pageToken and initilizing it with None
      next_page_token = None

      #This while loop runs until the pageToken becomes none and False , until that it get all the videos id form the playlist
      while True:
            #Now requesting the youtube to get video ids of the playlist from playlistItems()
            playlistItems_request = youtube_call.playlistItems().list(
                  part = "snippet,id",
                  playlistId = playlist_id,
                  maxResults = 50,
                  pageToken = next_page_token
            )
            playlistItem_response = playlistItems_request.execute()

            #To get all the videos id mention in the maxResults we are using for loop and appending that id's into the list
            for i in  range(len(playlistItem_response["items"])):
                  video_id = playlistItem_response["items"][i]["snippet"]["resourceId"]["videoId"]
                  video_idlist.append(video_id)
            next_page_token = playlistItem_response.get("nextPageToken")
            if next_page_token == None:
                  break
      return video_idlist

# %%
video_id_call = get_video_ids("UCnz-ZXXER4jOvuED5trXfEA")

# %%
video_id_call
# Out:
# ['6lI0q2DV8DY',
#  'nzJJP-uDIZc',
#  'BNmoCYk58mU',
#  'W5Wvyc9Pass',
#  'oedv5lR3w_g',
#  'HiscSRv7zWk',
#  'PLN28d0PoFU',
#  'GxmrInUIMAE',
#  'D0-Qy7yk5TQ',
#  'GHtX0QXfi6g',
#  '0QcEqFrhb_Y',
#  'smztq8sRAhk',
#  '7skZzocEU6c',
#  'LZGaRcDxj8I',
#  'rBPQ5fg_kiY',
#  'hvwltYazuQo',
#  'a-hFbr-4VQQ',
#  'pMNcPLc9Z7c',
#  'zZKb8FQRShs',
#  'jS5_hjFgfzA',
#  '6UAU79FNBjQ',
#  'ZwFfiadQB3k',
#  'Det4ZjBSe3M',
#  'xUsY2jWQa1w',
#  'ueOUSjdAZY8',
#  '90iK6gGvG_g',
#  'hsaPfEvForM',
#  'jb8XlF2dkoY',
#  'WhkNQ3g0U64',
#  '_suB8xV9aPc',
#  'dWHSt0BVlv0',
#  'xJVWL7eMir0',
#  'h48xzQR3wNQ',
#  'S5gX-LLAZIM',
#  'LNlzx-YX8rI',
#  'WzkBZ0byoYE',
#  'weCZ1WynbMI',
#  '3dOxGYkpVbE',
#  '9dLXZrw6nac',
#  'i3xK7Nc414Q',
#  'H7YMumanHBA',
#  '4p-G7fGhqRk',
#  'yLR1w4tZ36I',
#  '-DiOp9vAEuM',
#  'O1o9m9T1c3k',
#  '7hZYh9qXxe4',
#  'aE623ff7zkM',
#  'eXJGjbDo5KY',
#  'O52sweYbCyI',
#  'cLSxasHg9WY',
#  'l6XhSFAyvO0',
#  'nJIEIzF7tDw',
#  'RehbnzKHS28',
#  '0OQJDd3QqQM',
#  'V6KPbGLYL4A',
#  'OIqm909GYYo',
#  'xN2PRAd8IZQ',
#  'AK7_m-aThfw',
#  'CYszyA2Xzdg',
#  'wT9ICgxRPYY',
#  'XruOBp7yPXU',
#  'SwSbnmqk3zY',
#  '8p_OzqIJ_p4',
#  '0Hhqf8L-b_0',
#  'M2NzvnfS-hI',
#  'QNfnuK-1YYY',
#  'PuBadaR8qC4',
#  'FNYdBLwZ6cE',
#  'zAmJPdZu8Rg',
#  'HJAwAKwFX-A',
#  'kY5HtrkjSj0',
#  'LCVSmkyB4v8',
#  '6x7vHXfRAP0',
#  '-DrSbc8B0WI',
#  'gsa1oFn9n0M',
#  'Ww71knvhQ-s',
#  'Jsnw6HLASZA',
#  'V_BozMwoYe4',
#  '0wjPsKDrYt8',
#  '1-z9ptlBar4',
#  '35dXEQJkFE8',
#  'jgNB4GN1UaQ',
#  'fhxByMe0mq8',
#  '5bwpXLHzZRo',
#  'UzOnFDmoJ9w',
#  'HNChkuE6HyA',
#  '2gFqUWO-AWM',
#  'NvdSKgQcyuc',
#  'BBb_duZIusU',
#  'PRGkYivK2xI',
#  'M323OL6K5vs',
#  'i7BjHjRafU8',
#  'r2asdRpr3uw',
#  'Hl4NZB1XR9c',
#  '1aybOgni7lI',
#  'j09EQ-xlh88',
#  '7nzTDrio7vY',
#  'J-uCLHTIWZ4',
#  '_BMPh5M4BIY']

# %%
len(video_id_call)
# Out:
# 18

# %%
#Now going to get video details like video name, likes , dislikes count and others
def get_video_details(video_detailslist_id):
    video_detailslist = []
    for i in video_detailslist_id:
        video_request = youtube_call.videos().list(
            part = "id,snippet,contentDetails,statistics",
            id = i 
        )
        video_response = video_request.execute()
        for i in video_response["items"]:
            video_data = {
                "channel_title" : i["snippet"]["channelTitle"],
                "channel_id" : i["snippet"]["channelId"],
                "video_title" : i["snippet"]["title"],
                "video_id" : i["id"],
                "video_thumnails" : i["snippet"]["thumbnails"]["default"]["url"],
                "video_publishDate" : i["snippet"]["publishedAt"],
                "video_duration" : i["contentDetails"]["duration"],
                "video_view" : i["statistics"].get("viewCount",),
                "video_likes" : i["statistics"].get("likeCount"),
                "video_favorite" : i["statistics"].get("favoriteCount"),
                "video_comments" : i["statistics"].get("commentCount"),
                "video_captionStatus" : i["contentDetails"]["caption"]

            }
        video_detailslist.append(video_data)
    return video_detailslist

# %%
#Here video_d_call is the variable where we stored the video ids in a list in get_video_ids function
video_details_call = get_video_details(video_id_call)

# %%
video_details_call
# Out:
# [{'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Cricket Match Problem | Solving SQL Interview Problem',
#   'video_id': '6lI0q2DV8DY',
#   'video_thumnails': 'https://i.ytimg.com/vi/6lI0q2DV8DY/default.jpg',
#   'video_publishDate': '2023-10-18T14:44:40Z',
#   'video_duration': 'PT16M8S',
#   'video_view': '17154',
#   'video_likes': '762',
#   'video_favorite': '0',
#   'video_comments': '60',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving an SQL Interview Problem | Find Child - Parent - Grandparent Hierarchy using SQL',
#   'video_id': 'nzJJP-uDIZc',
#   'video_thumnails': 'https://i.ytimg.com/vi/nzJJP-uDIZc/default.jpg',
#   'video_publishDate': '2023-10-04T13:30:12Z',
#   'video_duration': 'PT13M47S',
#   'video_view': '22723',
#   'video_likes': '729',
#   'video_favorite': '0',
#   'video_comments': '54',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'From 16 years of CAREER GAP To becoming a Software Engineer | How to get a JOB after a career gap',
#   'video_id': 'BNmoCYk58mU',
#   'video_thumnails': 'https://i.ytimg.com/vi/BNmoCYk58mU/default.jpg',
#   'video_publishDate': '2023-09-21T13:00:15Z',
#   'video_duration': 'PT24M28S',
#   'video_view': '13093',
#   'video_likes': '380',
#   'video_favorite': '0',
#   'video_comments': '76',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': '3 SQL Queries Asked in Interview for Business Analyst - Solved',
#   'video_id': 'W5Wvyc9Pass',
#   'video_thumnails': 'https://i.ytimg.com/vi/W5Wvyc9Pass/default.jpg',
#   'video_publishDate': '2023-09-13T13:00:23Z',
#   'video_duration': 'PT36M27S',
#   'video_view': '33501',
#   'video_likes': '1212',
#   'video_favorite': '0',
#   'video_comments': '80',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Courses You Can Take To Get Into Data Analytics',
#   'video_id': 'oedv5lR3w_g',
#   'video_thumnails': 'https://i.ytimg.com/vi/oedv5lR3w_g/default.jpg',
#   'video_publishDate': '2023-09-02T13:00:12Z',
#   'video_duration': 'PT6M59S',
#   'video_view': '20366',
#   'video_likes': '465',
#   'video_favorite': '0',
#   'video_comments': '72',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving a Real SQL Interview Problem | Job Vacancies SQL Query',
#   'video_id': 'HiscSRv7zWk',
#   'video_thumnails': 'https://i.ytimg.com/vi/HiscSRv7zWk/default.jpg',
#   'video_publishDate': '2023-08-25T13:00:09Z',
#   'video_duration': 'PT16M57S',
#   'video_view': '43033',
#   'video_likes': '1534',
#   'video_favorite': '0',
#   'video_comments': '130',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Python Bootcamp for Beginners | Python Course | Live Training',
#   'video_id': 'PLN28d0PoFU',
#   'video_thumnails': 'https://i.ytimg.com/vi/PLN28d0PoFU/default.jpg',
#   'video_publishDate': '2023-08-20T08:17:01Z',
#   'video_duration': 'PT54S',
#   'video_view': '5593',
#   'video_likes': '221',
#   'video_favorite': '0',
#   'video_comments': '35',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Data Analytics Project (PART 3) | Data Analyst Portfolio Project',
#   'video_id': 'GxmrInUIMAE',
#   'video_thumnails': 'https://i.ytimg.com/vi/GxmrInUIMAE/default.jpg',
#   'video_publishDate': '2023-08-19T13:14:46Z',
#   'video_duration': 'PT39M28S',
#   'video_view': '9473',
#   'video_likes': '330',
#   'video_favorite': '0',
#   'video_comments': '36',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Data Analytics Project (PART 2) | Data Analyst Portfolio Project',
#   'video_id': 'D0-Qy7yk5TQ',
#   'video_thumnails': 'https://i.ytimg.com/vi/D0-Qy7yk5TQ/default.jpg',
#   'video_publishDate': '2023-08-06T13:00:08Z',
#   'video_duration': 'PT44M14S',
#   'video_view': '15132',
#   'video_likes': '428',
#   'video_favorite': '0',
#   'video_comments': '52',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Data Analytics Project (PART 1) | Data Analyst Portfolio Project',
#   'video_id': 'GHtX0QXfi6g',
#   'video_thumnails': 'https://i.ytimg.com/vi/GHtX0QXfi6g/default.jpg',
#   'video_publishDate': '2023-08-04T13:00:11Z',
#   'video_duration': 'PT35M49S',
#   'video_view': '77647',
#   'video_likes': '2359',
#   'video_favorite': '0',
#   'video_comments': '168',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Learn SQL from me | Live SQL Training | SQL Bootcamp',
#   'video_id': '0QcEqFrhb_Y',
#   'video_thumnails': 'https://i.ytimg.com/vi/0QcEqFrhb_Y/default.jpg',
#   'video_publishDate': '2023-05-25T14:35:13Z',
#   'video_duration': 'PT9M51S',
#   'video_view': '23223',
#   'video_likes': '642',
#   'video_favorite': '0',
#   'video_comments': '180',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Learn Python here | Learn Python Programming here',
#   'video_id': 'smztq8sRAhk',
#   'video_thumnails': 'https://i.ytimg.com/vi/smztq8sRAhk/default.jpg',
#   'video_publishDate': '2023-05-16T13:45:59Z',
#   'video_duration': 'PT6M30S',
#   'video_view': '15221',
#   'video_likes': '280',
#   'video_favorite': '0',
#   'video_comments': '25',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving a Complex SQL Interview problem | Practice SQL Queries',
#   'video_id': '7skZzocEU6c',
#   'video_thumnails': 'https://i.ytimg.com/vi/7skZzocEU6c/default.jpg',
#   'video_publishDate': '2023-03-21T13:00:12Z',
#   'video_duration': 'PT32M9S',
#   'video_view': '42927',
#   'video_likes': '1218',
#   'video_favorite': '0',
#   'video_comments': '112',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'REAL SQL Interview Problem | Hierarchical data in SQL',
#   'video_id': 'LZGaRcDxj8I',
#   'video_thumnails': 'https://i.ytimg.com/vi/LZGaRcDxj8I/default.jpg',
#   'video_publishDate': '2023-03-14T13:00:09Z',
#   'video_duration': 'PT22M9S',
#   'video_view': '24617',
#   'video_likes': '904',
#   'video_favorite': '0',
#   'video_comments': '65',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Complete guide to Database Normalization in SQL',
#   'video_id': 'rBPQ5fg_kiY',
#   'video_thumnails': 'https://i.ytimg.com/vi/rBPQ5fg_kiY/default.jpg',
#   'video_publishDate': '2023-03-07T13:00:07Z',
#   'video_duration': 'PT40M51S',
#   'video_view': '78090',
#   'video_likes': '3386',
#   'video_favorite': '0',
#   'video_comments': '267',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Live class on Lighthall | Learn SQL from Basic to Advance in SQL Bootcamp',
#   'video_id': 'hvwltYazuQo',
#   'video_thumnails': 'https://i.ytimg.com/vi/hvwltYazuQo/default.jpg',
#   'video_publishDate': '2023-01-26T07:00:07Z',
#   'video_duration': 'PT6M46S',
#   'video_view': '13186',
#   'video_likes': '257',
#   'video_favorite': '0',
#   'video_comments': '152',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'How to learn SQL for free | Roadmap to learning SQL',
#   'video_id': 'a-hFbr-4VQQ',
#   'video_thumnails': 'https://i.ytimg.com/vi/a-hFbr-4VQQ/default.jpg',
#   'video_publishDate': '2022-12-28T13:00:10Z',
#   'video_duration': 'PT27M20S',
#   'video_view': '509564',
#   'video_likes': '15110',
#   'video_favorite': '0',
#   'video_comments': '437',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving an SQL Interview Problem',
#   'video_id': 'pMNcPLc9Z7c',
#   'video_thumnails': 'https://i.ytimg.com/vi/pMNcPLc9Z7c/default.jpg',
#   'video_publishDate': '2022-12-18T13:39:48Z',
#   'video_duration': 'PT27S',
#   'video_view': '42456',
#   'video_likes': '1674',
#   'video_favorite': '0',
#   'video_comments': '21',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving SQL Interview Query | Find Tree Node type using SQL',
#   'video_id': 'zZKb8FQRShs',
#   'video_thumnails': 'https://i.ytimg.com/vi/zZKb8FQRShs/default.jpg',
#   'video_publishDate': '2022-12-12T13:30:15Z',
#   'video_duration': 'PT9M43S',
#   'video_view': '22215',
#   'video_likes': '935',
#   'video_favorite': '0',
#   'video_comments': '54',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving SQL Interview Query for Data Analyst asked by a Product based company',
#   'video_id': 'jS5_hjFgfzA',
#   'video_thumnails': 'https://i.ytimg.com/vi/jS5_hjFgfzA/default.jpg',
#   'video_publishDate': '2022-12-07T13:25:28Z',
#   'video_duration': 'PT18M37S',
#   'video_view': '467250',
#   'video_likes': '10483',
#   'video_favorite': '0',
#   'video_comments': '312',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving a tricky SQL Interview Query',
#   'video_id': '6UAU79FNBjQ',
#   'video_thumnails': 'https://i.ytimg.com/vi/6UAU79FNBjQ/default.jpg',
#   'video_publishDate': '2022-11-21T13:00:04Z',
#   'video_duration': 'PT19M24S',
#   'video_view': '46065',
#   'video_likes': '1588',
#   'video_favorite': '0',
#   'video_comments': '127',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Interview Query for Data Analyst',
#   'video_id': 'ZwFfiadQB3k',
#   'video_thumnails': 'https://i.ytimg.com/vi/ZwFfiadQB3k/default.jpg',
#   'video_publishDate': '2022-11-14T13:00:17Z',
#   'video_duration': 'PT29M51S',
#   'video_view': '52204',
#   'video_likes': '1843',
#   'video_favorite': '0',
#   'video_comments': '76',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving a Complex SQL Interview Problem | Find the Most Modified File Extension',
#   'video_id': 'Det4ZjBSe3M',
#   'video_thumnails': 'https://i.ytimg.com/vi/Det4ZjBSe3M/default.jpg',
#   'video_publishDate': '2022-10-31T13:00:16Z',
#   'video_duration': 'PT22M30S',
#   'video_view': '26456',
#   'video_likes': '1012',
#   'video_favorite': '0',
#   'video_comments': '76',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL JOINS Interview Question | What does different SQL Joins return?',
#   'video_id': 'xUsY2jWQa1w',
#   'video_thumnails': 'https://i.ytimg.com/vi/xUsY2jWQa1w/default.jpg',
#   'video_publishDate': '2022-10-24T13:30:12Z',
#   'video_duration': 'PT25M17S',
#   'video_view': '288004',
#   'video_likes': '8777',
#   'video_favorite': '0',
#   'video_comments': '436',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Google SQL Interview Problem | Solving SQL Interview Query',
#   'video_id': 'ueOUSjdAZY8',
#   'video_thumnails': 'https://i.ytimg.com/vi/ueOUSjdAZY8/default.jpg',
#   'video_publishDate': '2022-10-10T13:00:28Z',
#   'video_duration': 'PT14M22S',
#   'video_view': '35476',
#   'video_likes': '1323',
#   'video_favorite': '0',
#   'video_comments': '129',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Interview Problem asked by Product Based Company | Solving SQL Interview Query',
#   'video_id': '90iK6gGvG_g',
#   'video_thumnails': 'https://i.ytimg.com/vi/90iK6gGvG_g/default.jpg',
#   'video_publishDate': '2022-10-05T13:13:21Z',
#   'video_duration': 'PT9M22S',
#   'video_view': '57546',
#   'video_likes': '2178',
#   'video_favorite': '0',
#   'video_comments': '136',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'How to become a Data Analyst FASTER ?',
#   'video_id': 'hsaPfEvForM',
#   'video_thumnails': 'https://i.ytimg.com/vi/hsaPfEvForM/default.jpg',
#   'video_publishDate': '2022-09-30T13:44:54Z',
#   'video_duration': 'PT16M20S',
#   'video_view': '96165',
#   'video_likes': '4047',
#   'video_favorite': '0',
#   'video_comments': '189',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Tricky SQL Interview Query | Practice Solving SQL Interview Queries',
#   'video_id': 'jb8XlF2dkoY',
#   'video_thumnails': 'https://i.ytimg.com/vi/jb8XlF2dkoY/default.jpg',
#   'video_publishDate': '2022-09-22T13:00:26Z',
#   'video_duration': 'PT12M34S',
#   'video_view': '29368',
#   'video_likes': '887',
#   'video_favorite': '0',
#   'video_comments': '101',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving SQL Interview Query using a "VERY IMPORTANT SQL concept"',
#   'video_id': 'WhkNQ3g0U64',
#   'video_thumnails': 'https://i.ytimg.com/vi/WhkNQ3g0U64/default.jpg',
#   'video_publishDate': '2022-09-19T13:00:17Z',
#   'video_duration': 'PT9M38S',
#   'video_view': '100969',
#   'video_likes': '2454',
#   'video_favorite': '0',
#   'video_comments': '183',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving SQL Interview Query | SQL Problem by Service based company',
#   'video_id': '_suB8xV9aPc',
#   'video_thumnails': 'https://i.ytimg.com/vi/_suB8xV9aPc/default.jpg',
#   'video_publishDate': '2022-09-16T13:00:32Z',
#   'video_duration': 'PT9M19S',
#   'video_view': '31183',
#   'video_likes': '1137',
#   'video_favorite': '0',
#   'video_comments': '74',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Practice SQL Interview Query | Big 4 Interview Question',
#   'video_id': 'dWHSt0BVlv0',
#   'video_thumnails': 'https://i.ytimg.com/vi/dWHSt0BVlv0/default.jpg',
#   'video_publishDate': '2022-09-12T13:00:33Z',
#   'video_duration': 'PT14M47S',
#   'video_view': '93658',
#   'video_likes': '3376',
#   'video_favorite': '0',
#   'video_comments': '179',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving SQL Interview Query | Ungroup given input data | FAANG Interview Query',
#   'video_id': 'xJVWL7eMir0',
#   'video_thumnails': 'https://i.ytimg.com/vi/xJVWL7eMir0/default.jpg',
#   'video_publishDate': '2022-09-08T13:00:36Z',
#   'video_duration': 'PT14M23S',
#   'video_view': '36502',
#   'video_likes': '1081',
#   'video_favorite': '0',
#   'video_comments': '83',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'How to remove Duplicate Data in SQL | SQL Query to remove duplicate',
#   'video_id': 'h48xzQR3wNQ',
#   'video_thumnails': 'https://i.ytimg.com/vi/h48xzQR3wNQ/default.jpg',
#   'video_publishDate': '2022-09-02T13:29:46Z',
#   'video_duration': 'PT37M31S',
#   'video_view': '252103',
#   'video_likes': '6107',
#   'video_favorite': '0',
#   'video_comments': '249',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving Complex SQL Query from HackerRank | SQL Interview Query',
#   'video_id': 'S5gX-LLAZIM',
#   'video_thumnails': 'https://i.ytimg.com/vi/S5gX-LLAZIM/default.jpg',
#   'video_publishDate': '2022-08-10T13:56:09Z',
#   'video_duration': 'PT38M22S',
#   'video_view': '63849',
#   'video_likes': '1597',
#   'video_favorite': '0',
#   'video_comments': '146',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Data Analyst vs Business Analyst | What should you choose?',
#   'video_id': 'LNlzx-YX8rI',
#   'video_thumnails': 'https://i.ytimg.com/vi/LNlzx-YX8rI/default.jpg',
#   'video_publishDate': '2022-07-26T12:45:01Z',
#   'video_duration': 'PT10M1S',
#   'video_view': '28169',
#   'video_likes': '1225',
#   'video_favorite': '0',
#   'video_comments': '110',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Materialized View in SQL | Faster SQL Queries using Materialized Views',
#   'video_id': 'WzkBZ0byoYE',
#   'video_thumnails': 'https://i.ytimg.com/vi/WzkBZ0byoYE/default.jpg',
#   'video_publishDate': '2022-07-07T13:04:22Z',
#   'video_duration': 'PT16M40S',
#   'video_view': '70668',
#   'video_likes': '1845',
#   'video_favorite': '0',
#   'video_comments': '174',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Learn SQL the right way | SQL Live Training | Learn SQL from me',
#   'video_id': 'weCZ1WynbMI',
#   'video_thumnails': 'https://i.ytimg.com/vi/weCZ1WynbMI/default.jpg',
#   'video_publishDate': '2022-06-28T14:30:13Z',
#   'video_duration': 'PT16M6S',
#   'video_view': '31753',
#   'video_likes': '597',
#   'video_favorite': '0',
#   'video_comments': '190',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Interview Assignment Queries | REAL SQL Assignment given in Interview Part 2 (Query Solution)',
#   'video_id': '3dOxGYkpVbE',
#   'video_thumnails': 'https://i.ytimg.com/vi/3dOxGYkpVbE/default.jpg',
#   'video_publishDate': '2022-06-21T14:10:42Z',
#   'video_duration': 'PT30M16S',
#   'video_view': '24713',
#   'video_likes': '591',
#   'video_favorite': '0',
#   'video_comments': '51',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Interview Assignment Queries | REAL SQL Assignment given in Interview Part 1 (Problem Statement)',
#   'video_id': '9dLXZrw6nac',
#   'video_thumnails': 'https://i.ytimg.com/vi/9dLXZrw6nac/default.jpg',
#   'video_publishDate': '2022-06-17T13:30:02Z',
#   'video_duration': 'PT8M17S',
#   'video_view': '20020',
#   'video_likes': '580',
#   'video_favorite': '0',
#   'video_comments': '80',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'REAL SQL Interview Question | Complex SQL Interview Query and Solution',
#   'video_id': 'i3xK7Nc414Q',
#   'video_thumnails': 'https://i.ytimg.com/vi/i3xK7Nc414Q/default.jpg',
#   'video_publishDate': '2022-06-03T13:35:34Z',
#   'video_duration': 'PT37M16S',
#   'video_view': '58510',
#   'video_likes': '1431',
#   'video_favorite': '0',
#   'video_comments': '116',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Top 10 Tips for JOB Interview | Tips for Job Interview',
#   'video_id': 'H7YMumanHBA',
#   'video_thumnails': 'https://i.ytimg.com/vi/H7YMumanHBA/default.jpg',
#   'video_publishDate': '2022-05-25T13:00:15Z',
#   'video_duration': 'PT10M44S',
#   'video_view': '15004',
#   'video_likes': '585',
#   'video_favorite': '0',
#   'video_comments': '45',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving SQL Query | Rows to Column in SQL',
#   'video_id': '4p-G7fGhqRk',
#   'video_thumnails': 'https://i.ytimg.com/vi/4p-G7fGhqRk/default.jpg',
#   'video_publishDate': '2022-05-18T13:21:24Z',
#   'video_duration': 'PT1H13M11S',
#   'video_view': '126321',
#   'video_likes': '3258',
#   'video_favorite': '0',
#   'video_comments': '165',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Procedure Tutorial in SQL | SQL Stored Procedure | Procedure in SQL',
#   'video_id': 'yLR1w4tZ36I',
#   'video_thumnails': 'https://i.ytimg.com/vi/yLR1w4tZ36I/default.jpg',
#   'video_publishDate': '2022-05-01T03:28:03Z',
#   'video_duration': 'PT1H6M21S',
#   'video_view': '192013',
#   'video_likes': '3700',
#   'video_favorite': '0',
#   'video_comments': '186',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'my Live SQL Course Announcement #shorts',
#   'video_id': '-DiOp9vAEuM',
#   'video_thumnails': 'https://i.ytimg.com/vi/-DiOp9vAEuM/default.jpg',
#   'video_publishDate': '2022-04-05T08:50:58Z',
#   'video_duration': 'PT59S',
#   'video_view': '21303',
#   'video_likes': '929',
#   'video_favorite': '0',
#   'video_comments': '86',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Best Online SQL Course to practically learn and practice SQL',
#   'video_id': 'O1o9m9T1c3k',
#   'video_thumnails': 'https://i.ytimg.com/vi/O1o9m9T1c3k/default.jpg',
#   'video_publishDate': '2022-03-30T14:35:14Z',
#   'video_duration': 'PT12M20S',
#   'video_view': '30107',
#   'video_likes': '558',
#   'video_favorite': '0',
#   'video_comments': '118',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Recursive SQL Queries Tutorial | Learn to write SQL Queries using Recursion',
#   'video_id': '7hZYh9qXxe4',
#   'video_thumnails': 'https://i.ytimg.com/vi/7hZYh9qXxe4/default.jpg',
#   'video_publishDate': '2022-03-23T15:36:43Z',
#   'video_duration': 'PT33M52S',
#   'video_view': '145694',
#   'video_likes': '3756',
#   'video_favorite': '0',
#   'video_comments': '257',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Solving SQL Interview Queries | Tricky SQL Interview Queries',
#   'video_id': 'aE623ff7zkM',
#   'video_thumnails': 'https://i.ytimg.com/vi/aE623ff7zkM/default.jpg',
#   'video_publishDate': '2022-03-16T14:27:54Z',
#   'video_duration': 'PT37M22S',
#   'video_view': '223120',
#   'video_likes': '5662',
#   'video_favorite': '0',
#   'video_comments': '427',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'How to learn SQL | Step by Step Guide on how to learn SQL',
#   'video_id': 'eXJGjbDo5KY',
#   'video_thumnails': 'https://i.ytimg.com/vi/eXJGjbDo5KY/default.jpg',
#   'video_publishDate': '2022-03-02T13:27:49Z',
#   'video_duration': 'PT23M30S',
#   'video_view': '132971',
#   'video_likes': '4690',
#   'video_favorite': '0',
#   'video_comments': '340',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'ANSI vs Non ANSI Joins in SQL | SQL Query Writing using ANSI and Non ANSI method',
#   'video_id': 'O52sweYbCyI',
#   'video_thumnails': 'https://i.ytimg.com/vi/O52sweYbCyI/default.jpg',
#   'video_publishDate': '2022-02-23T13:58:34Z',
#   'video_duration': 'PT32M13S',
#   'video_view': '31918',
#   'video_likes': '702',
#   'video_favorite': '0',
#   'video_comments': '84',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Views Tutorial | VIEWS in SQL Complete Tutorial',
#   'video_id': 'cLSxasHg9WY',
#   'video_thumnails': 'https://i.ytimg.com/vi/cLSxasHg9WY/default.jpg',
#   'video_publishDate': '2022-02-15T13:00:16Z',
#   'video_duration': 'PT43M20S',
#   'video_view': '191792',
#   'video_likes': '4253',
#   'video_favorite': '0',
#   'video_comments': '350',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Practice Writing SQL Queries on StrataScratch | How to Solve SQL Queries',
#   'video_id': 'l6XhSFAyvO0',
#   'video_thumnails': 'https://i.ytimg.com/vi/l6XhSFAyvO0/default.jpg',
#   'video_publishDate': '2022-02-08T13:59:30Z',
#   'video_duration': 'PT45M40S',
#   'video_view': '132736',
#   'video_likes': '3376',
#   'video_favorite': '0',
#   'video_comments': '188',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Subquery in SQL | Correlated Subquery + Complete SQL Subqueries Tutorial',
#   'video_id': 'nJIEIzF7tDw',
#   'video_thumnails': 'https://i.ytimg.com/vi/nJIEIzF7tDw/default.jpg',
#   'video_publishDate': '2022-02-01T13:00:24Z',
#   'video_duration': 'PT1H10M44S',
#   'video_view': '770906',
#   'video_likes': '17755',
#   'video_favorite': '0',
#   'video_comments': '1042',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL JOINS Tutorial for beginners | Practice SQL Queries using JOINS - Part 2',
#   'video_id': 'RehbnzKHS28',
#   'video_thumnails': 'https://i.ytimg.com/vi/RehbnzKHS28/default.jpg',
#   'video_publishDate': '2022-01-14T13:00:30Z',
#   'video_duration': 'PT29M59S',
#   'video_view': '234452',
#   'video_likes': '7642',
#   'video_favorite': '0',
#   'video_comments': '514',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL JOINS Tutorial for beginners | Practice SQL Queries using JOINS - Part 1',
#   'video_id': '0OQJDd3QqQM',
#   'video_thumnails': 'https://i.ytimg.com/vi/0OQJDd3QqQM/default.jpg',
#   'video_publishDate': '2022-01-06T13:00:00Z',
#   'video_duration': 'PT35M23S',
#   'video_view': '660691',
#   'video_likes': '15795',
#   'video_favorite': '0',
#   'video_comments': '982',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'How to get your 1st DATA ANALYST Job | Data Analyst Job | How to become a Data Analyst',
#   'video_id': 'V6KPbGLYL4A',
#   'video_thumnails': 'https://i.ytimg.com/vi/V6KPbGLYL4A/default.jpg',
#   'video_publishDate': '2021-12-29T14:58:00Z',
#   'video_duration': 'PT22M47S',
#   'video_view': '332623',
#   'video_likes': '12630',
#   'video_favorite': '0',
#   'video_comments': '1042',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'BEST Online Courses to Learn SQL and Practice SQL Queries | BEST SQL Courses',
#   'video_id': 'OIqm909GYYo',
#   'video_thumnails': 'https://i.ytimg.com/vi/OIqm909GYYo/default.jpg',
#   'video_publishDate': '2021-12-22T13:11:25Z',
#   'video_duration': 'PT9M11S',
#   'video_view': '50076',
#   'video_likes': '1195',
#   'video_favorite': '0',
#   'video_comments': '138',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'REAL SQL Interview Question by a FAANG company | SQL Interview Query and Solution',
#   'video_id': 'xN2PRAd8IZQ',
#   'video_thumnails': 'https://i.ytimg.com/vi/xN2PRAd8IZQ/default.jpg',
#   'video_publishDate': '2021-12-08T13:00:37Z',
#   'video_duration': 'PT46M47S',
#   'video_view': '223083',
#   'video_likes': '4846',
#   'video_favorite': '0',
#   'video_comments': '287',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Top 25 SQL Interview Questions and Answers(The BEST SQL Interview Questions)',
#   'video_id': 'AK7_m-aThfw',
#   'video_thumnails': 'https://i.ytimg.com/vi/AK7_m-aThfw/default.jpg',
#   'video_publishDate': '2021-12-01T13:00:04Z',
#   'video_duration': 'PT26M21S',
#   'video_view': '663867',
#   'video_likes': '22195',
#   'video_favorite': '0',
#   'video_comments': '549',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Practice SQL Interview Questions on LeetCode | Solve SQL Interview Questions (Practice SQL Queries)',
#   'video_id': 'CYszyA2Xzdg',
#   'video_thumnails': 'https://i.ytimg.com/vi/CYszyA2Xzdg/default.jpg',
#   'video_publishDate': '2021-11-18T13:00:11Z',
#   'video_duration': 'PT49M54S',
#   'video_view': '77966',
#   'video_likes': '2213',
#   'video_favorite': '0',
#   'video_comments': '122',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Thank you for 10,000 Subscribers | Answering some of your questions',
#   'video_id': 'wT9ICgxRPYY',
#   'video_thumnails': 'https://i.ytimg.com/vi/wT9ICgxRPYY/default.jpg',
#   'video_publishDate': '2021-11-06T13:15:04Z',
#   'video_duration': 'PT9M36S',
#   'video_view': '2171',
#   'video_likes': '105',
#   'video_favorite': '0',
#   'video_comments': '84',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Practice Writing SQL Queries using Real Dataset(Practice Complex SQL Queries)',
#   'video_id': 'XruOBp7yPXU',
#   'video_thumnails': 'https://i.ytimg.com/vi/XruOBp7yPXU/default.jpg',
#   'video_publishDate': '2021-10-28T13:30:05Z',
#   'video_duration': 'PT54M41S',
#   'video_view': '185939',
#   'video_likes': '5974',
#   'video_favorite': '0',
#   'video_comments': '343',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Python Project to Scrape YouTube using YouTube Data API | Analyze and Visualize YouTube data',
#   'video_id': 'SwSbnmqk3zY',
#   'video_thumnails': 'https://i.ytimg.com/vi/SwSbnmqk3zY/default.jpg',
#   'video_publishDate': '2021-10-13T13:00:13Z',
#   'video_duration': 'PT1H9M34S',
#   'video_view': '102114',
#   'video_likes': '3115',
#   'video_favorite': '0',
#   'video_comments': '241',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Practice Complex SQL Queries | SQL Query to fetch N consecutive records',
#   'video_id': '8p_OzqIJ_p4',
#   'video_thumnails': 'https://i.ytimg.com/vi/8p_OzqIJ_p4/default.jpg',
#   'video_publishDate': '2021-09-28T15:30:01Z',
#   'video_duration': 'PT25M33S',
#   'video_view': '69656',
#   'video_likes': '2381',
#   'video_favorite': '0',
#   'video_comments': '181',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'ANACONDA Tutorial for Python | How to Install Anaconda on Mac OS and How to use Anaconda for Python',
#   'video_id': '0Hhqf8L-b_0',
#   'video_thumnails': 'https://i.ytimg.com/vi/0Hhqf8L-b_0/default.jpg',
#   'video_publishDate': '2021-09-21T13:00:00Z',
#   'video_duration': 'PT19M57S',
#   'video_view': '91234',
#   'video_likes': '1528',
#   'video_favorite': '0',
#   'video_comments': '83',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Connect to PostgreSQL from Python (Using SQL in Python) | Python to PostgreSQL',
#   'video_id': 'M2NzvnfS-hI',
#   'video_thumnails': 'https://i.ytimg.com/vi/M2NzvnfS-hI/default.jpg',
#   'video_publishDate': '2021-09-13T11:54:03Z',
#   'video_duration': 'PT22M58S',
#   'video_view': '113903',
#   'video_likes': '2773',
#   'video_favorite': '0',
#   'video_comments': '148',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL WITH Clause | How to write SQL Queries using WITH Clause | SQL CTE (Common Table Expression)',
#   'video_id': 'QNfnuK-1YYY',
#   'video_thumnails': 'https://i.ytimg.com/vi/QNfnuK-1YYY/default.jpg',
#   'video_publishDate': '2021-09-05T13:37:33Z',
#   'video_duration': 'PT24M48S',
#   'video_view': '425791',
#   'video_likes': '10410',
#   'video_favorite': '0',
#   'video_comments': '594',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'STEP by STEP guide to Learn Python | How to learn PYTHON',
#   'video_id': 'PuBadaR8qC4',
#   'video_thumnails': 'https://i.ytimg.com/vi/PuBadaR8qC4/default.jpg',
#   'video_publishDate': '2021-08-29T14:34:03Z',
#   'video_duration': 'PT9M32S',
#   'video_view': '10345',
#   'video_likes': '507',
#   'video_favorite': '0',
#   'video_comments': '46',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Learn how to write SQL Queries(Practice Complex SQL Queries)',
#   'video_id': 'FNYdBLwZ6cE',
#   'video_thumnails': 'https://i.ytimg.com/vi/FNYdBLwZ6cE/default.jpg',
#   'video_publishDate': '2021-08-22T12:54:58Z',
#   'video_duration': 'PT49M56S',
#   'video_view': '1321718',
#   'video_likes': '30033',
#   'video_favorite': '0',
#   'video_comments': '1056',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Window Function | How to write SQL Query using Frame Clause, CUME_DIST | SQL Queries Tutorial',
#   'video_id': 'zAmJPdZu8Rg',
#   'video_thumnails': 'https://i.ytimg.com/vi/zAmJPdZu8Rg/default.jpg',
#   'video_publishDate': '2021-08-13T17:28:34Z',
#   'video_duration': 'PT54M31S',
#   'video_view': '263921',
#   'video_likes': '9299',
#   'video_favorite': '0',
#   'video_comments': '607',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Learn how to use GitHub for Beginners | GitHub Tutorial',
#   'video_id': 'HJAwAKwFX-A',
#   'video_thumnails': 'https://i.ytimg.com/vi/HJAwAKwFX-A/default.jpg',
#   'video_publishDate': '2021-08-06T13:58:43Z',
#   'video_duration': 'PT23M9S',
#   'video_view': '65066',
#   'video_likes': '1735',
#   'video_favorite': '0',
#   'video_comments': '65',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Git Tutorial for Complete Beginners | Learn Git in 35 minutes',
#   'video_id': 'kY5HtrkjSj0',
#   'video_thumnails': 'https://i.ytimg.com/vi/kY5HtrkjSj0/default.jpg',
#   'video_publishDate': '2021-07-16T12:00:32Z',
#   'video_duration': 'PT36M39S',
#   'video_view': '44502',
#   'video_likes': '1560',
#   'video_favorite': '0',
#   'video_comments': '137',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Web Scraping in Python using Beautiful Soup | Writing a Python program to Scrape IMDB website',
#   'video_id': 'LCVSmkyB4v8',
#   'video_thumnails': 'https://i.ytimg.com/vi/LCVSmkyB4v8/default.jpg',
#   'video_publishDate': '2021-07-05T12:00:04Z',
#   'video_duration': 'PT37M30S',
#   'video_view': '139732',
#   'video_likes': '4585',
#   'video_favorite': '0',
#   'video_comments': '363',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Thank you for 1000 subscribers | Channel update | Who am i? & What i do?',
#   'video_id': '6x7vHXfRAP0',
#   'video_thumnails': 'https://i.ytimg.com/vi/6x7vHXfRAP0/default.jpg',
#   'video_publishDate': '2021-06-23T12:00:02Z',
#   'video_duration': 'PT4M22S',
#   'video_view': '6100',
#   'video_likes': '152',
#   'video_favorite': '0',
#   'video_comments': '63',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Practice SQL and Python | How to Practice Programming | Using LeetCode',
#   'video_id': '-DrSbc8B0WI',
#   'video_thumnails': 'https://i.ytimg.com/vi/-DrSbc8B0WI/default.jpg',
#   'video_publishDate': '2021-06-08T11:52:31Z',
#   'video_duration': 'PT8M57S',
#   'video_view': '39374',
#   'video_likes': '1134',
#   'video_favorite': '0',
#   'video_comments': '51',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Logging Tutorial in Python | DON’T use Print for logging | How to Log messages in Python',
#   'video_id': 'gsa1oFn9n0M',
#   'video_thumnails': 'https://i.ytimg.com/vi/gsa1oFn9n0M/default.jpg',
#   'video_publishDate': '2021-06-04T13:51:51Z',
#   'video_duration': 'PT28M55S',
#   'video_view': '37203',
#   'video_likes': '884',
#   'video_favorite': '0',
#   'video_comments': '63',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Window Function | How to write SQL Query using RANK, DENSE RANK, LEAD/LAG | SQL Queries Tutorial',
#   'video_id': 'Ww71knvhQ-s',
#   'video_thumnails': 'https://i.ytimg.com/vi/Ww71knvhQ-s/default.jpg',
#   'video_publishDate': '2021-05-21T12:47:47Z',
#   'video_duration': 'PT24M55S',
#   'video_view': '761245',
#   'video_likes': '23799',
#   'video_favorite': '0',
#   'video_comments': '1239',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'How to Read and Write Files in Python | File Handling Tutorial in Python',
#   'video_id': 'Jsnw6HLASZA',
#   'video_thumnails': 'https://i.ytimg.com/vi/Jsnw6HLASZA/default.jpg',
#   'video_publishDate': '2021-05-05T12:29:03Z',
#   'video_duration': 'PT19M30S',
#   'video_view': '11907',
#   'video_likes': '422',
#   'video_favorite': '0',
#   'video_comments': '38',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Regular Expressions in Python | Regular Expressions Python Tutorial',
#   'video_id': 'V_BozMwoYe4',
#   'video_thumnails': 'https://i.ytimg.com/vi/V_BozMwoYe4/default.jpg',
#   'video_publishDate': '2021-04-22T12:00:18Z',
#   'video_duration': 'PT46M41S',
#   'video_view': '13375',
#   'video_likes': '394',
#   'video_favorite': '0',
#   'video_comments': '69',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'What is Data Science (for beginners) | Data Science for Beginners | Data Science Life Cycle',
#   'video_id': '0wjPsKDrYt8',
#   'video_thumnails': 'https://i.ytimg.com/vi/0wjPsKDrYt8/default.jpg',
#   'video_publishDate': '2021-04-08T12:00:01Z',
#   'video_duration': 'PT5M49S',
#   'video_view': '5095',
#   'video_likes': '166',
#   'video_favorite': '0',
#   'video_comments': '10',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Best Resume Format | Tips for writing an AWESOME Resume | ATS Resume Format',
#   'video_id': '1-z9ptlBar4',
#   'video_thumnails': 'https://i.ytimg.com/vi/1-z9ptlBar4/default.jpg',
#   'video_publishDate': '2021-03-25T12:23:51Z',
#   'video_duration': 'PT9M58S',
#   'video_view': '132295',
#   'video_likes': '3931',
#   'video_favorite': '0',
#   'video_comments': '198',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Dictionary in Python (for beginners) | Python Dictionaries | Python Tutorial #10',
#   'video_id': '35dXEQJkFE8',
#   'video_thumnails': 'https://i.ytimg.com/vi/35dXEQJkFE8/default.jpg',
#   'video_publishDate': '2021-03-18T12:00:31Z',
#   'video_duration': 'PT12M58S',
#   'video_view': '3305',
#   'video_likes': '89',
#   'video_favorite': '0',
#   'video_comments': '7',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Lists in Python EXPLAINED | Python Lists | Python Tutorial for Beginners #9',
#   'video_id': 'jgNB4GN1UaQ',
#   'video_thumnails': 'https://i.ytimg.com/vi/jgNB4GN1UaQ/default.jpg',
#   'video_publishDate': '2021-03-11T12:00:23Z',
#   'video_duration': 'PT19M40S',
#   'video_view': '3197',
#   'video_likes': '91',
#   'video_favorite': '0',
#   'video_comments': '9',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Exception Handling in Python | TRY EXCEPT in Python | Python Tutorial for Beginners #8',
#   'video_id': 'fhxByMe0mq8',
#   'video_thumnails': 'https://i.ytimg.com/vi/fhxByMe0mq8/default.jpg',
#   'video_publishDate': '2021-03-04T12:28:53Z',
#   'video_duration': 'PT14M53S',
#   'video_view': '15757',
#   'video_likes': '397',
#   'video_favorite': '0',
#   'video_comments': '19',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Local and Global Scope in Python | Local and Global Variables | Python Tutorial for Beginners #7',
#   'video_id': '5bwpXLHzZRo',
#   'video_thumnails': 'https://i.ytimg.com/vi/5bwpXLHzZRo/default.jpg',
#   'video_publishDate': '2021-03-01T13:00:02Z',
#   'video_duration': 'PT11M26S',
#   'video_view': '4979',
#   'video_likes': '153',
#   'video_favorite': '0',
#   'video_comments': '9',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'What is a FUNCTION in Python | Python Functions | Python Tutorial for Beginners #6',
#   'video_id': 'UzOnFDmoJ9w',
#   'video_thumnails': 'https://i.ytimg.com/vi/UzOnFDmoJ9w/default.jpg',
#   'video_publishDate': '2021-02-22T13:00:25Z',
#   'video_duration': 'PT9M57S',
#   'video_view': '3311',
#   'video_likes': '96',
#   'video_favorite': '0',
#   'video_comments': '7',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Import modules in Python | Import module from different directory | Python Tutorial for beginners #5',
#   'video_id': 'HNChkuE6HyA',
#   'video_thumnails': 'https://i.ytimg.com/vi/HNChkuE6HyA/default.jpg',
#   'video_publishDate': '2021-02-14T13:01:01Z',
#   'video_duration': 'PT18M41S',
#   'video_view': '56295',
#   'video_likes': '793',
#   'video_favorite': '0',
#   'video_comments': '80',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'WHILE loop and FOR loop in Python | LOOP statements in Python | Python Tutorial for Beginners #4',
#   'video_id': '2gFqUWO-AWM',
#   'video_thumnails': 'https://i.ytimg.com/vi/2gFqUWO-AWM/default.jpg',
#   'video_publishDate': '2021-02-07T13:25:13Z',
#   'video_duration': 'PT29M30S',
#   'video_view': '5110',
#   'video_likes': '142',
#   'video_favorite': '0',
#   'video_comments': '27',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'IF ELSE ELIF statement in Python | IF ELSE Statement in Python | Python Tutorial for Beginners #3',
#   'video_id': 'NvdSKgQcyuc',
#   'video_thumnails': 'https://i.ytimg.com/vi/NvdSKgQcyuc/default.jpg',
#   'video_publishDate': '2021-01-31T14:58:15Z',
#   'video_duration': 'PT23M55S',
#   'video_view': '3806',
#   'video_likes': '107',
#   'video_favorite': '0',
#   'video_comments': '12',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'What is a VARIABLE in Python | Python Variables | Python Tutorial for Beginners #2',
#   'video_id': 'BBb_duZIusU',
#   'video_thumnails': 'https://i.ytimg.com/vi/BBb_duZIusU/default.jpg',
#   'video_publishDate': '2021-01-25T00:00:05Z',
#   'video_duration': 'PT12M24S',
#   'video_view': '3857',
#   'video_likes': '123',
#   'video_favorite': '0',
#   'video_comments': '16',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'What is DATA TYPE, OPERATORS and EXPRESSION in Python | Python Tutorial for Beginners #1',
#   'video_id': 'PRGkYivK2xI',
#   'video_thumnails': 'https://i.ytimg.com/vi/PRGkYivK2xI/default.jpg',
#   'video_publishDate': '2021-01-18T00:08:54Z',
#   'video_duration': 'PT11M21S',
#   'video_view': '6647',
#   'video_likes': '174',
#   'video_favorite': '0',
#   'video_comments': '19',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'How to Install Python on Mac OS and How to Run Python code',
#   'video_id': 'M323OL6K5vs',
#   'video_thumnails': 'https://i.ytimg.com/vi/M323OL6K5vs/default.jpg',
#   'video_publishDate': '2021-01-11T00:49:40Z',
#   'video_duration': 'PT9M54S',
#   'video_view': '522533',
#   'video_likes': '6754',
#   'video_favorite': '0',
#   'video_comments': '364',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Excel Alternative: How to use SQL to perform EXCEL tasks (SQL for Data Analysis)',
#   'video_id': 'i7BjHjRafU8',
#   'video_thumnails': 'https://i.ytimg.com/vi/i7BjHjRafU8/default.jpg',
#   'video_publishDate': '2021-01-03T13:42:37Z',
#   'video_duration': 'PT9M59S',
#   'video_view': '32599',
#   'video_likes': '730',
#   'video_favorite': '0',
#   'video_comments': '50',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'iPhone 12 Pro Unboxing | 5 Reasons to BUY iPhone 12 Pro',
#   'video_id': 'r2asdRpr3uw',
#   'video_thumnails': 'https://i.ytimg.com/vi/r2asdRpr3uw/default.jpg',
#   'video_publishDate': '2020-12-15T00:15:50Z',
#   'video_duration': 'PT5M12S',
#   'video_view': '1217',
#   'video_likes': '38',
#   'video_favorite': '0',
#   'video_comments': '24',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'SQL Basics Tutorial for Beginners (Practice SQL Queries)',
#   'video_id': 'Hl4NZB1XR9c',
#   'video_thumnails': 'https://i.ytimg.com/vi/Hl4NZB1XR9c/default.jpg',
#   'video_publishDate': '2020-12-11T02:10:35Z',
#   'video_duration': 'PT1H10M21S',
#   'video_view': '942708',
#   'video_likes': '20465',
#   'video_favorite': '0',
#   'video_comments': '625',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'How to install PostgreSQL on Mac OS | Install and Uninstall PostgreSQL Database',
#   'video_id': '1aybOgni7lI',
#   'video_thumnails': 'https://i.ytimg.com/vi/1aybOgni7lI/default.jpg',
#   'video_publishDate': '2020-11-16T02:28:09Z',
#   'video_duration': 'PT20M51S',
#   'video_view': '87453',
#   'video_likes': '816',
#   'video_favorite': '0',
#   'video_comments': '103',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Learn What is Database | Types of Database | DBMS',
#   'video_id': 'j09EQ-xlh88',
#   'video_thumnails': 'https://i.ytimg.com/vi/j09EQ-xlh88/default.jpg',
#   'video_publishDate': '2020-08-30T00:38:24Z',
#   'video_duration': 'PT12M11S',
#   'video_view': '267553',
#   'video_likes': '4581',
#   'video_favorite': '0',
#   'video_comments': '141',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'Do you need a Smartwatch',
#   'video_id': '7nzTDrio7vY',
#   'video_thumnails': 'https://i.ytimg.com/vi/7nzTDrio7vY/default.jpg',
#   'video_publishDate': '2020-07-12T15:32:36Z',
#   'video_duration': 'PT7M43S',
#   'video_view': '11479',
#   'video_likes': '185',
#   'video_favorite': '0',
#   'video_comments': '46',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'MacBook Pro 13 2020  One Week Later Review',
#   'video_id': 'J-uCLHTIWZ4',
#   'video_thumnails': 'https://i.ytimg.com/vi/J-uCLHTIWZ4/default.jpg',
#   'video_publishDate': '2020-06-29T15:03:19Z',
#   'video_duration': 'PT9M24S',
#   'video_view': '1432',
#   'video_likes': '73',
#   'video_favorite': '0',
#   'video_comments': '20',
#   'video_captionStatus': 'false'},
#  {'channel_title': 'techTFQ',
#   'channel_id': 'UCnz-ZXXER4jOvuED5trXfEA',
#   'video_title': 'MacBook Pro 13 2020 Unboxing',
#   'video_id': '_BMPh5M4BIY',
#   'video_thumnails': 'https://i.ytimg.com/vi/_BMPh5M4BIY/default.jpg',
#   'video_publishDate': '2020-06-22T14:49:50Z',
#   'video_duration': 'PT9M19S',
#   'video_view': '2715',
#   'video_likes': '95',
#   'video_favorite': '0',
#   'video_comments': '29',
#   'video_captionStatus': 'false'}]

# %%
len(video_details_call)
# Out:
# 18

# %%
#Now we are going to get the comments
def get_comment_details(video_ids):
    comment_detaillist = []
    try:
        for i in video_ids:
                comment_request = youtube_call.commentThreads().list(
                    part = "snippet,id,replies",
                    videoId = i,
                    maxResults = 50
                )
                comment_response = comment_request.execute()

                for i in comment_response["items"]:
                    comment_data = {
                        "comment_id" : i["id"],
                        "video_id" : i["snippet"]["topLevelComment"]["snippet"]["videoId"],
                        "comment_text" : i["snippet"]["topLevelComment"]["snippet"]["textDisplay"],
                        "comment_author" :i["snippet"]["topLevelComment"]["snippet"]["authorDisplayName"],
                        "comment_publishdate" :i["snippet"]["topLevelComment"]["snippet"]["publishedAt"]
                    }
                    comment_detaillist.append(comment_data)
    except:
          pass
    return comment_detaillist

# %%
comment_detailslist_call = get_comment_details(video_id_call)

# %%
comment_detailslist_call
# Out:
# [{'comment_id': 'UgwvxGJ9395SKlgxIkp4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Plsql bootcamp please',
#   'comment_author': 'Anudeep Reddy',
#   'comment_publishdate': '2023-11-12T00:02:26Z'},
#  {'comment_id': 'UgyFJlN_Kks8HN4TAn14AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'can someone help me how to use cte.  .    i am a beginner help me with sql',
#   'comment_author': 'shyam kumar',
#   'comment_publishdate': '2023-11-11T11:10:00Z'},
#  {'comment_id': 'UgyAN6tNOPJOXyBf2dx4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Enjoyed your SQL interview tips! 🚀 I&#39;ve just kicked off a channel diving into SQL questions and solutions. Would love your insights and feedback! Keep rocking the SQL world',
#   'comment_author': 'Data From Zero to Hero',
#   'comment_publishdate': '2023-11-09T17:23:01Z'},
#  {'comment_id': 'UgwrH1hOD5bGvB8o9XJ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Bhai ads jyada ho Gaye..',
#   'comment_author': 'Programmer Hrutik',
#   'comment_publishdate': '2023-11-06T17:07:46Z'},
#  {'comment_id': 'UgxEPIGSnD-MFx9I4ex4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': '5 runs are possible.<br>There should be wide+4.<br>No ball +4.<br>Overthrow 1+4.<br><br>There is a possibility of 5 runs.<br><br>Query was good. Please create a video more like this with new scenarios. Thank you!',
#   'comment_author': 'Chaitanya Inamdar',
#   'comment_publishdate': '2023-11-01T06:41:00Z'},
#  {'comment_id': 'UgyVmP3GBxNbUDdR5dd4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Thanks for sharing valuable knowledge,<br>Can you please suggest some extended technologies to learn , I have SQL/PLSQL real time experience...',
#   'comment_author': 'Zainul Abadin',
#   'comment_publishdate': '2023-11-01T06:18:09Z'},
#  {'comment_id': 'Ugzl0kAq-sx1AWlgz8R4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Hi TFQ, kindly make videos on power bi',
#   'comment_author': 'DEEPAK KUMAR',
#   'comment_publishdate': '2023-10-31T12:11:37Z'},
#  {'comment_id': 'UgyZXJhL7K7o5SD5rsl4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Sir when will be your new sql bootcamp',
#   'comment_author': 'Mounika Gundlapalli',
#   'comment_publishdate': '2023-10-31T10:18:48Z'},
#  {'comment_id': 'UgwShFNSjif1zLOqJNt4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Wide+4=5',
#   'comment_author': 'MOHAMMAD NADEEM Nadeem',
#   'comment_publishdate': '2023-10-30T16:08:22Z'},
#  {'comment_id': 'UgwWTd6NaWcgFf5ODBZ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Hi, this may look a bit cumbersome to review. <br>kindly review if the process in right. <br>I have used reverse table to get multiples of 6 at beginning, followed by flagging of multiples of 6, then a drop down operation, then aggregating the runs and reversing the order of overs. <br>Happy SQLing everyone.<br><br>-- reverse order to bring multiples of 6 at the beginning<br>with cte as (<br>Select<br>balls,<br>runs<br>from <br>table<br>order by balls desc<br><br>),<br><br>--flag multiples of 6 as 1 for drop down operation in next cte<br>balls_flag as (<br>Select<br>balls,<br>runs,<br>case when mod(balls,6) = 0 then 1 else 0 end as balls_flag<br>from <br>cte<br>),<br><br>-- use count aggregation with window function to create new row which will be used to aggregate runs over wise in next cte.<br>over_group as (<br>select <br>balls,<br>runs,<br>balls_flag,<br>count(balls_flag)over(order  by balls desc) as over_group<br>from <br>balls_flag<br>),<br><br>-- aggregate runs over wise by grouping on over_group. however output will give reverse order of over aggregation. eg runs in over 20 will be aggregated as over 1. this will be reversed in next cte<br>rev_over_sum as (<br>Select<br>over_group as over_rev,<br>sum(runs) as runs<br>from <br>over_group<br>group by 1<br>or<br>),<br><br>-- create new column using row number window function by ordering in desc order of over_rev<br>reorder_overs as (<br>Select<br>over_rev,<br>runs,<br>row_number()over(order by over_rev desc) as overs<br>from <br>rev_over_group<br>)<br><br>--select reversed overs and runs column to get desired results<br>Select<br>overs,<br>runs<br>from <br>reorder_overs',
#   'comment_author': 'Mithun KT',
#   'comment_publishdate': '2023-10-30T02:47:45Z'},
#  {'comment_id': 'Ugx6Aw6TYUqP-LpYljF4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Why functions are called as window functions in SQL',
#   'comment_author': 'Janardhan jana',
#   'comment_publishdate': '2023-10-28T03:04:33Z'},
#  {'comment_id': 'UgxQQZW0-qT5fhaIyTt4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'is ntile function divides the number of rows by ntile value ? in that case suppose if i have 152 balls.',
#   'comment_author': 'vineeth menon',
#   'comment_publishdate': '2023-10-26T15:55:45Z'},
#  {'comment_id': 'UgwIaZxiaa8NjPSlB214AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'can anybody tell me how to insert data in my sql server as some function is not supported',
#   'comment_author': 'Shivani',
#   'comment_publishdate': '2023-10-26T02:46:54Z'},
#  {'comment_id': 'UgzCw0c4JebHJbpaQKB4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': '4 wides',
#   'comment_author': 'Sobhik Saha',
#   'comment_publishdate': '2023-10-25T13:49:11Z'},
#  {'comment_id': 'UgyMGcXao33ZMGi-PLZ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Does SQL server got generate_Series function?',
#   'comment_author': 'Rajkumar Rajan',
#   'comment_publishdate': '2023-10-25T08:50:44Z'},
#  {'comment_id': 'Ugwhxox4B09uYVhaD6x4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'yes it was interesting',
#   'comment_author': 'Kanaparthi Lakshmikanth',
#   'comment_publishdate': '2023-10-25T06:38:16Z'},
#  {'comment_id': 'UgxgK7MhZthZS_Gem9Z4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'thank you for the video sir but can you explain the same in the MySQL workbench,  that would be really helpful',
#   'comment_author': 'Satyalekhya Dsln',
#   'comment_publishdate': '2023-10-25T04:09:34Z'},
#  {'comment_id': 'UgyYJlDpQYuzYKYzdWt4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'My approach will be. Creating a column named over. Where value will be quotient when divided by 6. Then group by it. <a href="https://www.youtube.com/watch?v=6lI0q2DV8DY&amp;t=12m47s">12:47</a>',
#   'comment_author': 'Aji Thomas',
#   'comment_publishdate': '2023-10-24T19:28:41Z'},
#  {'comment_id': 'UgwQZqQ2E8wp3go3t1J4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'It&#39;s possible to score five runs in one ball <br>First is wide + boundary and <br>Second 1 run + byes 4runs(thrown by fielder)',
#   'comment_author': 'Pavan Rebel',
#   'comment_publishdate': '2023-10-24T06:26:26Z'},
#  {'comment_id': 'UgwbK4IHikYG2dPVA6h4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Useful info Toufiq!!<br><br>I have tried the following way in snowflake:<br><br>with raw_data as <br>(select case when ball%6 != 0 then to_decimal(left(round(ball/6,1),1)+1) else to_decimal(ball/6) end as rank ,<br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 ball,<br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0 score from demo_db.public.cricket)<br><br>select\xa0\xa0\xa0 rank , sum(score) as runs<br>from raw_data<br>group by rank',
#   'comment_author': 'Saibabu Vasamsetti',
#   'comment_publishdate': '2023-10-23T17:56:44Z'},
#  {'comment_id': 'UgxeG8th5KPWit1VIRt4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': '################ My Solution in PostgreSQL ###################<br><br>with A <br>as <br>(<br>  select <br>  ceil(((balls/6)*1.0)+((balls%6)*0.1)) as over,<br>  * <br>from <br>  match_score)<br><br>select <br>over,<br>sum(runs) as score<br>from A<br>group by over<br>order by over',
#   'comment_author': 'Koushik T',
#   'comment_publishdate': '2023-10-23T15:36:59Z'},
#  {'comment_id': 'Ugy7e0fS_zMAtjEY2z54AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'i have a quesion in SQL <br>is it possible to connect with you on any platform to discuss about that problem ?',
#   'comment_author': 'ketan verma',
#   'comment_publishdate': '2023-10-23T15:02:22Z'},
#  {'comment_id': 'Ugwl7VOg8DJM0CmfN2J4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Thanks for sharing this video. Here is my approach:<br>SELECT<br>\tcase when balls%6=0 then balls/6 else (balls/6)+1 end as over,<br>        sum(runs) as score<br>FROM match_score<br>GROUP by 1;',
#   'comment_author': 'KisaanTuber',
#   'comment_publishdate': '2023-10-23T03:01:58Z'},
#  {'comment_id': 'Ugxr0AKYGmioOW9mByZ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Hello All, I felt the approach used in the video is little lengthier. Here is my solution for same<br><br>\r<br>;with cric_overs as -------- Data preparation\r<br>(\r<br>Select 1 AS balls,2 AS runs\r<br>union all\r<br>Select 2 AS balls,3 AS runs\r<br>union all\r<br>Select 3 AS balls,4 AS runs\r<br>union all\r<br>Select 4 AS balls,6 AS runs\r<br>union all\r<br>Select 5 AS balls,1 AS runs\r<br>union all\r<br>Select 6 AS balls,1 AS runs\r<br>union all\r<br>Select 7 AS balls,2 AS runs\r<br>union all\r<br>Select 8 AS balls,3 AS runs\r<br>union all\r<br>Select 9 AS balls,4 AS runs\r<br>union all\r<br>Select 10 AS balls,4 AS runs\r<br>union all\r<br>Select 11 AS balls,2 AS runs\r<br>union all\r<br>Select 12 AS balls,6 AS runs\r<br>union all\r<br>Select 13 AS balls,2 AS runs\r<br>union all\r<br>Select 14 AS balls,1 AS runs\r<br>union all\r<br>Select 15 AS balls,4 AS runs\r<br>union all\r<br>Select 16 AS balls,1 AS runs\r<br>union all\r<br>Select 17 AS balls,2 AS runs\r<br>union all\r<br>Select 18 AS balls,4 AS runs\r<br>) ------------------------------- Data preparation\r<br>------------------ logic that solves the problem ----------\r<br>,cte_flag as \r<br>(\r<br>Select\r<br>balls,\r<br>runs,\r<br>CASE\r<br>\twhen balls % 6 = 0 THEN balls / 6\r<br>\telse (balls / 6) + 1\r<br>end as overs\r<br>from cric_overs\r<br>)\r<br>select overs\r<br>,SUM(runs) as TotalRunsEachOver\r<br>from cte_flag\r<br>Group by overs\r<br>Order by overs',
#   'comment_author': 'Tarun Pothala',
#   'comment_publishdate': '2023-10-22T17:19:48Z'},
#  {'comment_id': 'UgzxElP8J7pm5WTcuB54AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'for MYSQL ?',
#   'comment_author': 'Rajish Nair',
#   'comment_publishdate': '2023-10-21T13:26:46Z'},
#  {'comment_id': 'Ugwc45Ok5HeUtDu2lFd4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Hi Toufiq ,can please tell me what is a use of Within group clause it will be helpful if take example',
#   'comment_author': 'KARTIK WAGH',
#   'comment_publishdate': '2023-10-20T14:20:51Z'},
#  {'comment_id': 'UgxS9XWPp1wf1le6PUR4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'But 5 runs can be scored if the ball is noball and the batsman hit 4 !!! if am not wrong please correct me',
#   'comment_author': 'Dr. Aravinda C V NMAMIT',
#   'comment_publishdate': '2023-10-20T10:30:46Z'},
#  {'comment_id': 'UgzmykwhToDO8__bO6t4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'with cte as (\r<br>\r<br>select balls,runs,(case\r<br>                           when balls % 6=0 then balls/6\r<br>\t\t\t\t\t\t   else balls/6+1\r<br>\t\t\t\t\t\t   end) as overs\r<br>from match_score)\r<br>\r<br>select  overs,sum(runs) runs_per_over\r<br>from cte\r<br>group by overs;',
#   'comment_author': 'Prasanna Chalamalasetti',
#   'comment_publishdate': '2023-10-20T05:25:49Z'},
#  {'comment_id': 'Ugwt9_uF-8HKZmX-ZJR4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Hello, sir! Could you please make a video about DCL or SQL Triggers?',
#   'comment_author': 'Kemjhon Ponce',
#   'comment_publishdate': '2023-10-19T23:35:06Z'},
#  {'comment_id': 'Ugw0l86jTdLYHs0DBSt4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': '5 runs are possible. Overthrows. Single + 4 overthrows, etc.',
#   'comment_author': 'Christopher Bird',
#   'comment_publishdate': '2023-10-19T22:34:05Z'},
#  {'comment_id': 'UgxpiRLAfVxBgyK6VAJ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'with cte as(\r<br>select balls, runs, ceil(balls/6) as over from match_score)\r<br>select over, sum(runs) from cte\r<br>group by over;',
#   'comment_author': 'Atish Pradhan',
#   'comment_publishdate': '2023-10-19T16:59:24Z'},
#  {'comment_id': 'UgzVmdXi11rxJ0h7LC54AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Another great tutorial thank you Toufic!',
#   'comment_author': 'Sohail Khan',
#   'comment_publishdate': '2023-10-19T11:26:52Z'},
#  {'comment_id': 'UgyUdTUChboAfmfpPv54AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Very interesting video, Ntile came to my mind at first for segregation of overs and count, this is because, I have watched your video in the past you explained, I learn new things from your vids. Thanks a lot. <br><br>My only concern is, generate series is not working in the ssms(sql server) that im using. Its compatibility is 130. <br>Can I use row_number to generate numbers until 120 or so.',
#   'comment_author': 'Shekhar K',
#   'comment_publishdate': '2023-10-19T11:25:25Z'},
#  {'comment_id': 'UgzmwSTWs2PiNn29IgJ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Hi First of all thank you , your videos have been really helpful. I tried visiting your blog but it wont open.',
#   'comment_author': 'Rithvik Shetty',
#   'comment_publishdate': '2023-10-19T07:26:18Z'},
#  {'comment_id': 'UgwQGEx7g13agbC2hyt4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Same was asked to me in a interview few months ago',
#   'comment_author': 'Karthik S N',
#   'comment_publishdate': '2023-10-19T05:18:00Z'},
#  {'comment_id': 'UgwMGDAfvPNERGcQQG94AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Man you are awesome',
#   'comment_author': 'manoj cheera',
#   'comment_publishdate': '2023-10-19T02:52:33Z'},
#  {'comment_id': 'Ugzqzy3Te0McvMr7LU94AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': '❤',
#   'comment_author': 'Bhushan sagar',
#   'comment_publishdate': '2023-10-19T01:55:15Z'},
#  {'comment_id': 'Ugw9iky4mzQFijtaMjJ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'while using Random function in microsoft sql server management the output are the same value to all the 120 Balls for e.g Balls 1, random value is 0.855, the value for remaining 119 balls are also showing the same random value as in ball 1 i.e 0.855. Plz let me know how to solve this pblm',
#   'comment_author': 'Daily Dairy 4U',
#   'comment_publishdate': '2023-10-18T20:08:12Z'},
#  {'comment_id': 'Ugw1m31MgyB_91d1lHB4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'I always learn new things from your video thanks brother',
#   'comment_author': 'Shrikant Shirsekar',
#   'comment_publishdate': '2023-10-18T18:45:15Z'},
#  {'comment_id': 'Ugywidq6MM1N91IgLxh4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': '@techtfq i need to extract data with the help of group_concat and the data should be populated columnwise . I mailed you many times and try to connect you on your website but still not getting any response. Require your help for extracting the data in mysql',
#   'comment_author': 'Rishabh Gupta',
#   'comment_publishdate': '2023-10-18T18:15:54Z'},
#  {'comment_id': 'Ugxcc-HuqeEFU_3KdgJ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'how about this method ...\r<br>\r<br>select ((balls-1)/6)+1 as balls, sum(runs) from cricket group by ((balls-1)/6)+1 order by 1;',
#   'comment_author': 'vidyasagar j Kollurkar',
#   'comment_publishdate': '2023-10-18T18:10:41Z'},
#  {'comment_id': 'UgxuwFGVqQZTBineM-d4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Very eloquently solved the problem with ease. Thank you @Techtfq',
#   'comment_author': 'Abul Hassan',
#   'comment_publishdate': '2023-10-18T17:31:01Z'},
#  {'comment_id': 'Ugw3W-wPPVSI40HNbMp4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'But we can score 5 runs in a single ball wide+four.',
#   'comment_author': 'pesforever2055 qz',
#   'comment_publishdate': '2023-10-18T17:04:38Z'},
#  {'comment_id': 'UgyHrzjd97XKCPEGW-54AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Thank you Toufiq! <br><br>I tried in the following way:<br>SELECT over_num, SUM(runs) tot_runs\r<br>FROM\r<br>    (\r<br>        SELECT ceil(balls / 6) over_num, m.runs\r<br>        FROM   match_score m\r<br>    )\r<br>GROUP BY   over_num\r<br>ORDER BY   over_num;<br><br>Note: Tested in Oracle SQL',
#   'comment_author': 'Priya Sarathy',
#   'comment_publishdate': '2023-10-18T16:48:37Z'},
#  {'comment_id': 'UgzEl-hP3HXYuZx2JRt4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Learnt something new things',
#   'comment_author': 'yogesh talaskar',
#   'comment_publishdate': '2023-10-18T16:44:02Z'},
#  {'comment_id': 'UgybAFOvz1qrvDuOwHx4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'i do not how but might be any window fun ?',
#   'comment_author': 'Virendra Trivedi',
#   'comment_publishdate': '2023-10-18T15:51:46Z'},
#  {'comment_id': 'Ugy-IeRFCmkYyRttT3J4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'great to know about ntile and random function and there use in sql',
#   'comment_author': 'Review By Anand ',
#   'comment_publishdate': '2023-10-18T15:51:12Z'},
#  {'comment_id': 'UgwNvgWfntzUtIoZVYh4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Awesome Mr Toufiq<br>New window function i learnt....<br><br>Thanks so much',
#   'comment_author': 'junaid khan',
#   'comment_publishdate': '2023-10-18T15:27:26Z'},
#  {'comment_id': 'UgxEOE8oERiRYDcsUUZ4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'Can we do by using case statement but lengthy code',
#   'comment_author': 'Mjeditz87',
#   'comment_publishdate': '2023-10-18T15:17:58Z'},
#  {'comment_id': 'Ugy5_DNh1bpSpQHb9Qx4AaABAg',
#   'video_id': '6lI0q2DV8DY',
#   'comment_text': 'learn new thing..',
#   'comment_author': 'Hitesh Malviya',
#   'comment_publishdate': '2023-10-18T15:03:34Z'},
#  {'comment_id': 'Ugz5Rd8nU9iTzeqsnbN4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'OdinSchool Bootcamp link: <a href="https://hubs.la/Q024h4NC0">https://hubs.la/Q024h4NC0</a><br>Success stories page link: <a href="https://hubs.la/Q024h4Xz0">https://hubs.la/Q024h4Xz0</a>',
#   'comment_author': 'techTFQ',
#   'comment_publishdate': '2023-10-05T20:20:42Z'},
#  {'comment_id': 'Ugzn40Inxuw4qdJyj7Z4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Plsql bootcamp please',
#   'comment_author': 'Anudeep Reddy',
#   'comment_publishdate': '2023-11-12T00:01:54Z'},
#  {'comment_id': 'UgwIbDaxImhf7gY_dWx4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'I am not sure whether I am right here but, this is what I understand.<br>Parent of B is Y and Y&#39;s grandparent is Y1 and the status of Y1 is Alive. Can you please help me understand why that record is not coming in your result set?',
#   'comment_author': 'Sameer Ambre',
#   'comment_publishdate': '2023-10-31T04:28:55Z'},
#  {'comment_id': 'UgxekWyz20vSX6j3w2B4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'JazakAllah.<br>Very convenient solution to a complex problem. May Allah bless you.',
#   'comment_author': '560 Faraz Ahmad',
#   'comment_publishdate': '2023-10-28T16:54:18Z'},
#  {'comment_id': 'UgwjSbjulEfOEpvE8hN4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'great',
#   'comment_author': 'vraj someshvari',
#   'comment_publishdate': '2023-10-22T17:54:22Z'},
#  {'comment_id': 'Ugw9oqLWgrlGDrrxhdl4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'I think this problem should be the best example for demoing the usecase for self join',
#   'comment_author': 'Bharathan Kumaran',
#   'comment_publishdate': '2023-10-22T05:12:24Z'},
#  {'comment_id': 'UgxjPeNl6yh_QLgUohl4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Thanks a lot , I understood everything, great explanation,<br>i question what  the last part select count( 1) , are we doing a grouping?',
#   'comment_author': 'Bharathan Kumaran',
#   'comment_publishdate': '2023-10-22T05:08:32Z'},
#  {'comment_id': 'UgwSMVbBMEBRdNi7m4N4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'select count(p.person) as persons from persons p inner join persons gp on p.parent = gp.person inner join persons gp2 on<br>       gp.parent = gp2.person where gp2.person_status = &#39;Alive&#39;;',
#   'comment_author': 'Varun Tirupati',
#   'comment_publishdate': '2023-10-19T18:45:17Z'},
#  {'comment_id': 'UgwHlhF86c8CJYD_f_h4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'posting before watching your solution:<br><br>SELECT C.PERSON AS CHILD,<br>C.PARENT AS PARENT,<br>P.PARENT AS GPARENT,<br>GP.PERSON_STATUS<br>  FROM STATUS C JOIN STATUS P ON C.PARENT = P.PERSON <br>  JOIN STATUS GP ON P.PARENT = GP.PERSON<br>WHERE GP.PERSON_STATUS = &#39;ALIVE&#39;;',
#   'comment_author': 'Paul Babu',
#   'comment_publishdate': '2023-10-18T09:16:46Z'},
#  {'comment_id': 'Ugw2piZKnCOUXfsEvMR4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'May Allah always be by your side my brother. You are like one of his greatest blessings on 🌎❤ The way you have explained and brought the best solution out is commendable! Ankit Bansal makes things over complicated, neither do I enjoy his style of teaching. We are meant to learn from you!',
#   'comment_author': 'Aviral Ojha',
#   'comment_publishdate': '2023-10-17T15:33:11Z'},
#  {'comment_id': 'Ugym0-AIMz5vR6Ea0hF4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Select count(1) from person a<br>Where status  =Alive<br>And exists<br>( select 1 from persons <br>Where a.parent = b. Person)',
#   'comment_author': 'Soundars Swag',
#   'comment_publishdate': '2023-10-16T05:34:18Z'},
#  {'comment_id': 'Ugy6h6qIMcJd4QFwBdp4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Hi sir, I have purchased SQL Bootcamp in your TechTFQ website. There is a problem which i am facing while learning. The website is logging out automatically serveral times in the middle of the sessions. I had to login several times repeatedly. Could you please look into it. It will be helpful if you could resolve the issue quickly. Thanks in advance.',
#   'comment_author': 'Thulasi 583',
#   'comment_publishdate': '2023-10-13T07:25:45Z'},
#  {'comment_id': 'Ugyf-2KM7-NVIQ3-vSF4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'with recursive parents as (<br>select person,parent,CAST(NULL as varchar(10)) as son, 1 as level from people where person not in (select parent from people)<br>union all<br>select p2.person,p2.parent,p1.person,level+1 from parents as p1 inner join people as p2 on p1.parent=p2.person where p2.status=&#39;Alive&#39;)<br>select count(*) from parents where level&gt;=3;',
#   'comment_author': 'Through My Glasses',
#   'comment_publishdate': '2023-10-13T06:54:35Z'},
#  {'comment_id': 'Ugwd1MEoW0in79OatU54AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': '################ My Solution using CTE ################<br><br>with A as (<br>select <br>  p1.person as person,<br>  p2.parent as grandparent <br>from <br>  persons p1<br>join<br>  persons p2<br>on <br>  p1.parent=p2.person)<br><br>select <br>count(A.person) as alive_count<br>from<br>A<br>join<br>persons p<br>on A.grandparent = p.person<br>where p.person_status=&#39;Alive&#39;',
#   'comment_author': 'Koushik T',
#   'comment_publishdate': '2023-10-13T04:45:17Z'},
#  {'comment_id': 'UgzwktnX019eW0ot7Y94AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Pks explain snowflakes in sql',
#   'comment_author': 'sss',
#   'comment_publishdate': '2023-10-13T03:58:04Z'},
#  {'comment_id': 'UgxbAegPRG687G-7p3R4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Hello, Would you please solve quastion like this for python(panda)?',
#   'comment_author': 'Parham Farjam',
#   'comment_publishdate': '2023-10-08T20:30:25Z'},
#  {'comment_id': 'Ugz1QI6XUZnJlcoSc3N4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Thank you sir, I developed my SQL with your videos only',
#   'comment_author': 'Greatlearning S',
#   'comment_publishdate': '2023-10-08T18:48:25Z'},
#  {'comment_id': 'UgzoCoAzEF59CYrQcp54AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Self join',
#   'comment_author': 'Rajendra kumar Ray',
#   'comment_publishdate': '2023-10-08T04:12:54Z'},
#  {'comment_id': 'UgwlGC96D4JyWJH4jlB4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Great explanation of self join<br>Thankyou sir for this video!',
#   'comment_author': 'Avi',
#   'comment_publishdate': '2023-10-07T16:59:45Z'},
#  {'comment_id': 'Ugx9sv6KuQu4CjHQh0Z4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Hello..\r<br>Thanks for always giving great lectures.\r<br>The solution you provided looked very concise and appealing.\r<br>However, I tried tackling it in a bit more complex manner.<br><br><br>WITH RECURSIVE r_query\r<br>AS (\r<br>\tSELECT person\r<br>\t     , parent\r<br>\t     , person_status\r<br>\t     , 1 clevel\r<br>\t     , concat(person, &#39;&#39;) cpath\r<br>\t  FROM ( SELECT psn_1.person\r<br>\t              , psn_1.parent\r<br>\t              , psn_1.person_status\r<br>\t\t\t\t  from persons psn_1 \r<br>\t\t\t\tUNION ALL  \r<br>\t\t\t\tSELECT person\r<br>\t\t\t\t     , parent\r<br>\t\t\t\t     , person_status\r<br>\t\t\t\t  FROM ( SELECT psn_1.parent person\r<br>\t\t\t\t              , NULL parent\r<br>\t\t\t\t              , NULL person_status\r<br>\t\t\t\t              , psn_2.person p_per\r<br>\t\t\t\t           from persons psn_1 LEFT OUTER JOIN persons psn_2\r<br>\t\t\t\t                              ON psn_2.person = psn_1.parent\r<br>\t\t\t\t         ) a\r<br>\t\t\t\t WHERE a.p_per IS NULL\r<br>\t\t\t\t) a\r<br>\t WHERE parent IS null \r<br>\tUNION all\r<br>\tSELECT a.person\r<br>\t     , a.parent\r<br>\t     , a.person_status\r<br>\t     , clevel + 1\r<br>\t     , concat(b.cpath, &#39;-&gt;&#39;, a.person) cpath\r<br>\t  FROM ( SELECT psn_1.person\r<br>\t              , psn_1.parent\r<br>\t              , psn_1.person_status\r<br>\t\t\t\t  from persons psn_1 \r<br>\t\t\t\tUNION ALL  \r<br>\t\t\t\tSELECT person\r<br>\t\t\t\t     , parent\r<br>\t\t\t\t     , person_status\r<br>\t\t\t\t  FROM ( SELECT psn_1.parent person\r<br>\t\t\t\t              , NULL parent\r<br>\t\t\t\t              , NULL person_status\r<br>\t\t\t\t              , psn_2.person p_per\r<br>\t\t\t\t           from persons psn_1 LEFT OUTER JOIN persons psn_2\r<br>\t\t\t\t                              ON psn_2.person = psn_1.parent\r<br>\t\t\t\t         ) a\r<br>\t\t\t\t WHERE a.p_per IS NULL\r<br>\t\t\t\t) a INNER JOIN r_query b\r<br>\t\t\t\t    ON b.person = a.parent\r<br> )\r<br> SELECT person\r<br>      , parent\r<br>      , person_status\r<br>   FROM r_query\r<br> WHERE person IN ( SELECT SPLIT_PART(cpath, &#39;-&gt;&#39;, -3)\r<br>                     FROM r_query\r<br>                   )\r<br>   AND person_status = &#39;Alive&#39;                   \r<br>;',
#   'comment_author': '이병훈',
#   'comment_publishdate': '2023-10-07T11:42:00Z'},
#  {'comment_id': 'UgwRsNBxx_z_PLVyJod4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Query solving with Odni school ad',
#   'comment_author': 'KrishnaKumarKumar',
#   'comment_publishdate': '2023-10-07T05:21:35Z'},
#  {'comment_id': 'UgymgS30KxDT0YSEZvV4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Thanks toufiq Bhai, for helping Data community and and sharing knowledge &amp; experience 😊, it helps a lot to understand self join',
#   'comment_author': 'Sami-ulla Makaandar',
#   'comment_publishdate': '2023-10-07T02:24:28Z'},
#  {'comment_id': 'Ugy2HDpH0IPt3CsYWA54AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'You are the BEST!',
#   'comment_author': 'Data AnalysT',
#   'comment_publishdate': '2023-10-06T21:06:20Z'},
#  {'comment_id': 'Ugwvli4OOnbm78FV3L14AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'great video as always, it was well explained.',
#   'comment_author': 'Jordan Tambeck',
#   'comment_publishdate': '2023-10-06T14:25:29Z'},
#  {'comment_id': 'UgzvNFJmmB6Ga2Dr7ht4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'This correlated sub-query  will yield the result as required  --- <br>select c.person from persons c where exists ( <br>select null from persons p where c.parent = p.person  and exists ( <br>  select null from persons g where g.person= p.parent <br>and g.status = &#39;Alive&#39;))',
#   'comment_author': 'kokku',
#   'comment_publishdate': '2023-10-05T22:54:23Z'},
#  {'comment_id': 'Ugycf_thPzbVcsfB4H94AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'sir.....please post sql classes from scratch......you said will post 1st week of September but not posted......please sir post those classes.......',
#   'comment_author': 'nivis world',
#   'comment_publishdate': '2023-10-05T19:44:50Z'},
#  {'comment_id': 'UgySD172RolcuzLUZH14AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'with table_A as <br>(<br>select t1.*,<br>t2.parent as grand_parents<br>from persons as t1<br>left join persons as t2<br>on t1.parent = t2.person<br>)<br><br>select count(*)<br>from table_A as t1<br>left join persons as t2<br>on t1.grand_parents = t2.person<br>where t2.person_status =&#39;Alive&#39;<br>;',
#   'comment_author': 'Rishabh Gupta',
#   'comment_publishdate': '2023-10-05T10:29:02Z'},
#  {'comment_id': 'UgxIiyPa3D55VSFIUz54AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Not be annoying but this is a dumb question. But I love your videos',
#   'comment_author': 'Dean Marko',
#   'comment_publishdate': '2023-10-05T08:55:16Z'},
#  {'comment_id': 'UgwCF71w_9LwupXipJV4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Thank you for sharing, nice explanation. When will you start postgresql Boot camp',
#   'comment_author': 'Krishna',
#   'comment_publishdate': '2023-10-05T08:26:10Z'},
#  {'comment_id': 'UgyLMmWg978ZCeGhbfp4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Very interesting problem! I like the way you dissect the problem into different parts, it makes easier to approach it! Thanks!👍👍',
#   'comment_author': 'Zewdu Wereta',
#   'comment_publishdate': '2023-10-05T07:53:11Z'},
#  {'comment_id': 'UgzUCH2UCsIgYZNsZQt4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Self join is the best way to answer this question',
#   'comment_author': 'kranti kumar',
#   'comment_publishdate': '2023-10-05T03:00:16Z'},
#  {'comment_id': 'UgyyQjJMcQg044Zrp0d4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Best tutor for SQL, easy to follow and very detailed explanation. Must follow and subscribe if you want to solve interesting SQL problems.',
#   'comment_author': 'Attila Pekka Szabó',
#   'comment_publishdate': '2023-10-05T00:23:19Z'},
#  {'comment_id': 'Ugx2qmzI9dp81DEz_Fx4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Great video again 👍👍',
#   'comment_author': 'Fathima Farahna',
#   'comment_publishdate': '2023-10-04T18:30:50Z'},
#  {'comment_id': 'UgyRIoR6gyRxcjRdjrx4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Please explain slow and clear <br>I didn&#39;t understand this vedio',
#   'comment_author': 'Chandu Muddasani',
#   'comment_publishdate': '2023-10-04T18:20:47Z'},
#  {'comment_id': 'Ugxu-taJe1mVC7UJJSR4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'hope this solution is acceptable -- <br><br>select P1.person as self, P2.person as Parent, P3.Person as GP, P1.person_status as GP_Status\r<br>from Persons as P1\r<br>Right join Persons as P2 on P1.parent = P2.Person\r<br>right join Persons as P3 on P2.parent = P3.Person\r<br>\r<br>where  P1.person_status = &#39;Alive&#39;',
#   'comment_author': 'Sachin Gunjal',
#   'comment_publishdate': '2023-10-04T18:10:46Z'},
#  {'comment_id': 'Ugx4ytc-QvBlOEMTQWN4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'I&#39;m facing a SQL interview question repeateadly. &quot;Why a stored preocedure is executing fine till yesterday and today it is taking long time to execute&quot; [indexes are not dropped/no changes to this query]. Can you please explain this question ?',
#   'comment_author': 'Swetha Veluguri',
#   'comment_publishdate': '2023-10-04T18:10:23Z'},
#  {'comment_id': 'UgzO8bE5mEdIe_gD6S14AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Solved the same kind of problem with scenario employee, manager, managers_ manager using self join',
#   'comment_author': 'Santhosh Kumar',
#   'comment_publishdate': '2023-10-04T17:34:52Z'},
#  {'comment_id': 'Ugz8CY7CTayacM8-5-R4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Self join',
#   'comment_author': 'Sumathy G',
#   'comment_publishdate': '2023-10-04T17:21:07Z'},
#  {'comment_id': 'Ugyi-ZNPLyzBobBSjlZ4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Tfq makes sql look so simple',
#   'comment_author': 'Mary the Analyst',
#   'comment_publishdate': '2023-10-04T16:38:58Z'},
#  {'comment_id': 'UgybnOoHWmzxd85BUWx4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Hi I want to triggers in postgresql',
#   'comment_author': 'Aravind T',
#   'comment_publishdate': '2023-10-04T16:32:10Z'},
#  {'comment_id': 'UgzZoQyKOSy0XeMYNqx4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Slefjoin a 1 with a2 on a1.person =a2.parent',
#   'comment_author': 'viswas kumar surapaneni',
#   'comment_publishdate': '2023-10-04T16:14:22Z'},
#  {'comment_id': 'UgwcdQFRIJPO68f5cap4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Self join is a solution',
#   'comment_author': 'Sreejesh j nair',
#   'comment_publishdate': '2023-10-04T16:05:22Z'},
#  {'comment_id': 'UgwJvQdtxzr-mKuQuo54AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Another way of writing query for same problem<br><br>with recursive cte1 as <br>(<br>select *<br>from test<br>where par_name in (select p_name from test)<br>),<br>cte2 as <br>(<br>select *, 1 as level<br>from cte1<br>union<br>select c1.*, level + 1 as level<br>from cte1 c1<br>join cte2 c2<br>    on c2.par_name = c1.p_name<br>)<br>select count(1)<br>from (<br>select <br> cte2.p_name,<br> cte2.par_name,<br> t.status <br>from cte2<br>join test t <br>    on cte2.par_name = t.p_name<br>where level = 2<br>and t.status = &#39;Alive&#39;<br>) subquery',
#   'comment_author': 'Swapnil Solanki',
#   'comment_publishdate': '2023-10-04T15:24:52Z'},
#  {'comment_id': 'UgzAqeFv2aV0MR_9D8l4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'We can use self join',
#   'comment_author': 'gontla kowshik',
#   'comment_publishdate': '2023-10-04T14:47:16Z'},
#  {'comment_id': 'UgwEBn8yanU0dzGYZbl4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Best explanation ever hard problems look like simple',
#   'comment_author': 'श्री उत्तम महाराज सरकटे आळंदी',
#   'comment_publishdate': '2023-10-04T14:34:20Z'},
#  {'comment_id': 'UgyJJAOSxG2ORPI7ozJ4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Please share this session also',
#   'comment_author': 'Ashish Tripathi',
#   'comment_publishdate': '2023-10-04T13:40:33Z'},
#  {'comment_id': 'UgxQG0wXKOIha5DiCqJ4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'self join',
#   'comment_author': 'shashi gowda R',
#   'comment_publishdate': '2023-10-04T13:38:14Z'},
#  {'comment_id': 'Ugyh2zASdXyTZ1X7T6h4AaABAg',
#   'video_id': 'nzJJP-uDIZc',
#   'comment_text': 'Natural joins',
#   'comment_author': 'Abhi Sai',
#   'comment_publishdate': '2023-10-04T13:37:13Z'},
#  {'comment_id': 'UgyecUYbbGBTpGUhARl4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Data science bootcamp taken by Angelina:<br><br><a href="https://hubs.la/Q022Q7G20">https://hubs.la/Q022Q7G20</a>',
#   'comment_author': 'techTFQ',
#   'comment_publishdate': '2023-09-21T16:11:59Z'},
#  {'comment_id': 'UgypKW7PQOt4aOtDM3p4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': '😁 promo sm',
#   'comment_author': 'Joy Satterfield',
#   'comment_publishdate': '2023-10-19T01:03:44Z'},
#  {'comment_id': 'UgxVr4IsE-Kfzrf_E7Z4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Very inspiring for us who want to try our career with long gap.. thank you..',
#   'comment_author': 'Shanta Murthy',
#   'comment_publishdate': '2023-10-15T21:54:58Z'},
#  {'comment_id': 'Ugz8EO2XnHzlT0qfJup4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'It&#39;s only possible for girls',
#   'comment_author': 'Dhanurdar Sahhu',
#   'comment_publishdate': '2023-10-15T02:57:06Z'},
#  {'comment_id': 'UgwrIYTlXHMoxaqO8ft4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Hi my name is shami, I am in non it profession right now, but I want to switch my career in to it and I HV interest in sql. Kindly suggest me.',
#   'comment_author': 'Syed Shami04',
#   'comment_publishdate': '2023-10-11T13:53:41Z'},
#  {'comment_id': 'UgyVbDUn_3DqAHFqinV4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'what ever you said it correct.but i didn&#39;t full fill parents dreams and financial situations ,till btech parents bear huge investment on my studies .so as per my pointify aftet btech its a very burden to bear extra amount on us.Parents and relatives and along with society also blaming and hatred on us. When we study hard also we didn&#39;t crack dsa for product based company although student can did and devote time on studies. Only for dsa preparation it takes nearly 6 to 8 months to master in dsa to slove that problems.<br>After college how to burden parents its a difficult challenge for middle class and poor people .If even in college they keep on devote time on studies and learning on Coding .First of all change world corporate mind set filtering is good for hiring but its a bad thing in some aspects.Even though we have positive mind set also.<br>Companies are playing with us like a ball.',
#   'comment_author': '19CSE 1088 kotni Kanaka Raju',
#   'comment_publishdate': '2023-10-05T16:16:40Z'},
#  {'comment_id': 'UgyTaQSnyopmRUXC8qJ4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'How can you teach one on one? I have some questions. Can you help?',
#   'comment_author': 'love freeman',
#   'comment_publishdate': '2023-09-29T14:25:29Z'},
#  {'comment_id': 'Ugzn6cLHjtNnM67CXnZ4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Is this bootcamp review real ? Or paid ?',
#   'comment_author': 'Mishal Qamar',
#   'comment_publishdate': '2023-09-28T17:46:01Z'},
#  {'comment_id': 'Ugx_ruZtaFnNDXk7TdJ4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'very informative video! must watch for everyone who are looking for career transition.',
#   'comment_author': 'Ayush Gupta',
#   'comment_publishdate': '2023-09-28T02:56:21Z'},
#  {'comment_id': 'UgydUVNb3M_puwk-zaB4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Awesome',
#   'comment_author': 'Adude',
#   'comment_publishdate': '2023-09-27T22:37:10Z'},
#  {'comment_id': 'UgzfL40s76f40c4SMKN4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Thumb nail should be Paid Ad from Odin school',
#   'comment_author': 'KrishnaKumarKumar',
#   'comment_publishdate': '2023-09-26T02:33:44Z'},
#  {'comment_id': 'UgzQ4TAZt13tqQgTodF4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Sir   please reply to this comment as i believe in you the most for this question PLEASE 🙏🙏🙏 REPLAY ITS VERY IMPORTANT FOR ME. <br><br>&quot;I am currently preparing for  a data analyst job and i really wanna know if is it still worth it in 2024 or if the job is being replace by gpt as many are saying this that there will be very few to no job job in data analyst field in coming time... <br><br>Please replay to this should I CONTINUE my preparation for data anylast or should i change it to something else. And are company  laying off employees related to this fields',
#   'comment_author': 'yogesh',
#   'comment_publishdate': '2023-09-25T13:06:04Z'},
#  {'comment_id': 'UgyvHS2nGRbQGZ2NinV4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Hii i want to talk with you',
#   'comment_author': 'Shaik Jaheer',
#   'comment_publishdate': '2023-09-24T16:27:55Z'},
#  {'comment_id': 'UgynbUN7R5-JA70qM0B4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'She has done data science bootcamp from Odinschol of data science',
#   'comment_author': 'Vidyut Singh',
#   'comment_publishdate': '2023-09-23T15:11:25Z'},
#  {'comment_id': 'UgzUYhhKamk_Nu0UDBR4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'If I go thr odinschool bootcamp page and check, they charge 99,000 + GST for course, I don&#39;t know how fair it is',
#   'comment_author': 'Tejasvi NTS',
#   'comment_publishdate': '2023-09-23T12:20:49Z'},
#  {'comment_id': 'Ugzd1NAM6MagLutRc2t4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'I have completed graduation in 2015 I&#39;m from non tech background but i want to develop my career in IT sector here is lotsw of gap...  now I&#39;m learning SQL through your videos &amp;w3 school is it heplful for me to get  a job',
#   'comment_author': 'Syed Kazmi',
#   'comment_publishdate': '2023-09-23T07:54:24Z'},
#  {'comment_id': 'Ugz9vcLJuOj5kcMbs0J4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Hello sir .... I completed my btech in cse 2014 .. i worked for a startup in manual and automation testing for few months and had to give up due to some other <br>personal reasons . Then i got married and kids and had a long gap ... now i want to resart my career  in testing again .. but my other family member&#39;s <br> Jobs are at risk and I am really confused now ... pleasedo suggest me',
#   'comment_author': 'shishira vyda',
#   'comment_publishdate': '2023-09-22T12:01:55Z'},
#  {'comment_id': 'UgxSCJ3cZ1ENS8ZRiVh4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'ur videos are always helpful',
#   'comment_author': 'Vijay Kumar Naramalli',
#   'comment_publishdate': '2023-09-22T10:20:47Z'},
#  {'comment_id': 'Ugw5qZwzbK-9WBWTRwJ4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'I am doing datascience boot camp from newton school  but the great difference between newton school and odin school is fees. newton school is charging approx 2.6 lakh for the same bootcamp for which most of the institutes are charging 70 to 1 lakh ... and shocking thing is after spending 2.6 lakh i am stumbling in the confusion that how much package they will provide by their side they are saying average of 5 lakhs but the same package has been provided by the other school as well which are charging half the amount.',
#   'comment_author': 'Rohit Guleria',
#   'comment_publishdate': '2023-09-22T09:37:05Z'},
#  {'comment_id': 'UgxqoqfycjedcmwP-z14AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Hi thoufiq,<br>I&#39;m completeted bachelor of computer applications, I&#39;m interested to set a path In SQL and database field. I&#39;m known basic of SQL. How to improve myself, if there is opportunity to learn and get job',
#   'comment_author': 'g parameswari',
#   'comment_publishdate': '2023-09-22T08:00:22Z'},
#  {'comment_id': 'UgzWUdMWLSw11tv5p5F4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Hi iam want to join ur boot camp on sql. How can i join now',
#   'comment_author': 'ramesh kumar',
#   'comment_publishdate': '2023-09-22T06:10:58Z'},
#  {'comment_id': 'Ugz6ZB44tsYwD53h5kd4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Did she joined as fresher or experienced?',
#   'comment_author': 'BR Edits 🤩😍',
#   'comment_publishdate': '2023-09-22T05:10:37Z'},
#  {'comment_id': 'UgywP_PGXlpXd13y6Yp4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Wow this was really inspiring 👏🏻 Great concept brother👌 Need more of such inspiring interactions',
#   'comment_author': 'Mohammed Shahil',
#   'comment_publishdate': '2023-09-22T02:19:50Z'},
#  {'comment_id': 'UgyKdHl-kos1l5FLFVB4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Excellent. Kudos to you and the interviewee. Very helpful.',
#   'comment_author': 'gautam shah',
#   'comment_publishdate': '2023-09-21T20:08:51Z'},
#  {'comment_id': 'UgzgS-SsdKvAr9VqLdl4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Its really inspiring , Thanks toufiq for bringing this vedio. I got some information how  to show the gap of my career even I&#39;m in same path of her.Thanks for motivating',
#   'comment_author': 'Vanitha V',
#   'comment_publishdate': '2023-09-21T17:19:33Z'},
#  {'comment_id': 'UgxKoF8lfa90WyV6WWB4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Excellent Thoufiq, you did amazing work and brought to us.',
#   'comment_author': 'Gopal Aare',
#   'comment_publishdate': '2023-09-21T14:56:43Z'},
#  {'comment_id': 'UgwGvqI_D9l4cTzyukR4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'How to get odinschool bootcamp',
#   'comment_author': 'Ganesh chittalwar',
#   'comment_publishdate': '2023-09-21T14:52:13Z'},
#  {'comment_id': 'UgxSz6HozXLTmPRPPt54AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Now whats her CTC? When entering 2022',
#   'comment_author': 'selva harishankar',
#   'comment_publishdate': '2023-09-21T14:36:59Z'},
#  {'comment_id': 'UgycCb8ykoKH5jlTRXF4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Really inspiring !',
#   'comment_author': 'Sadaf fatima',
#   'comment_publishdate': '2023-09-21T14:20:56Z'},
#  {'comment_id': 'Ugxh0gn3Lih7tBXBVw54AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': '@techTFQ I want to switch to Oracle development from QA Automation. Suggest a good path.',
#   'comment_author': 'KasiKarthi',
#   'comment_publishdate': '2023-09-21T14:01:34Z'},
#  {'comment_id': 'UgxGCBgGNyv6ptv5oiR4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'You&#39;re doing God&#39;s work for a lot of IT people. Very few people talk about career gap.',
#   'comment_author': 'Bikash Kar',
#   'comment_publishdate': '2023-09-21T13:46:57Z'},
#  {'comment_id': 'UgyHIix359tsAY6vV4d4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Ilanti vallu unnatha varaku,freshers ki small experience vallaki kastalu tappav',
#   'comment_author': 'ayyappa e116',
#   'comment_publishdate': '2023-09-21T13:33:38Z'},
#  {'comment_id': 'Ugw35D7yBw-t8TqzC694AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Amazing 💯💯',
#   'comment_author': 'Fathima Farahna',
#   'comment_publishdate': '2023-09-21T13:26:24Z'},
#  {'comment_id': 'UgyUCAgVRsaykUZi6154AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Odin advertising every where',
#   'comment_author': 'Naveen Khandelwal',
#   'comment_publishdate': '2023-09-21T13:17:23Z'},
#  {'comment_id': 'UgxLQDc4Y2kfhAktv7l4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Bro, Plz d add Timestamps...',
#   'comment_author': 'Gaz Khan',
#   'comment_publishdate': '2023-09-21T13:13:26Z'},
#  {'comment_id': 'UgzD-C86zbkgDS1IY6h4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'have 5 years career gap can I get into IT as fresher i have completed Oracle SQL And PLSQL',
#   'comment_author': 'Oracle SQL',
#   'comment_publishdate': '2023-09-21T13:11:37Z'},
#  {'comment_id': 'Ugwu6diimmROvpY002Z4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Inspiring 😊',
#   'comment_author': 'vishal karale',
#   'comment_publishdate': '2023-09-21T13:09:38Z'},
#  {'comment_id': 'Ugw7KOI0PSRRLMWunaF4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'How did you justify your gap in interviews?',
#   'comment_author': 'Md Nisar Ahmed',
#   'comment_publishdate': '2023-09-21T13:07:28Z'},
#  {'comment_id': 'UgzF_S5I33RsYqFNS-V4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': '❤',
#   'comment_author': 'anil rajput',
#   'comment_publishdate': '2023-09-21T13:02:16Z'},
#  {'comment_id': 'UgzNmoUa8nM2qoZ2l094AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Hi,',
#   'comment_author': 'KasiKarthi',
#   'comment_publishdate': '2023-09-21T13:01:17Z'},
#  {'comment_id': 'UgwZQXWA6Ru_AyEcGdp4AaABAg',
#   'video_id': 'BNmoCYk58mU',
#   'comment_text': 'Amazing bro',
#   'comment_author': 'Mohammed Vahid',
#   'comment_publishdate': '2023-09-21T09:00:10Z'},
#  {'comment_id': 'Ugz2VWKcSthugOMttvF4AaABAg',
#   'video_id': 'W5Wvyc9Pass',
#   'comment_text': 'Hi @techTFQ in the second query you have use group by clause on alias customer and status, but as per execution order group by is executed before select,  so when I tried running query you explained it throws me error invalid identifier, Cn you please let me know what to do. I am using Oracle SQL Developer',
#   'comment_author': 'Avinash Pratap Singh',
#   'comment_publishdate': '2023-11-15T08:08:58Z'},
#  {'comment_id': 'Ugw92yM3tXjPxzjx4A54AaABAg',
#   'video_id': 'W5Wvyc9Pass',
#   'comment_text': 'Thanks for this!',
#   'comment_author': 'Varun L',
#   'comment_publishdate': '2023-11-14T14:52:14Z'},
#  {'comment_id': 'UgwPae5dN370wasD2lV4AaABAg',
#   'video_id': 'W5Wvyc9Pass',
#   'comment_text': 'Please do more interview questions on mysql',
#   'comment_author': 'Rimarani Meher',
#   'comment_publishdate': '2023-11-11T04:51:48Z'},
#  {'comment_id': 'UgyBpzCBQyJEAuOxjad4AaABAg',
# ...
#   'comment_author': 'SP30305ATL',
#   'comment_publishdate': '2022-11-18T23:11:39Z'},
#  {'comment_id': 'UgyYYrRBhjNHMeF-8iB4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'for &quot;string_agg(file_ext, &#39;,&#39; order by file_ext desc) as extension&quot;, I did &quot;group_concat(file_ext order by date_modified separator &quot;,&quot;)&quot; for MySql.',
#   'comment_author': 'su meim',
#   'comment_publishdate': '2022-11-18T07:51:37Z'},
#  {'comment_id': 'Ugxc2EXA0WuiBsCczPV4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'I was thinking of using split_part instead of substring..other than that my solution was same',
#   'comment_author': 'Soutik Kumar',
#   'comment_publishdate': '2022-11-17T09:36:56Z'},
#  {'comment_id': 'UgyOoewH3VlfuZPNu3Z4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'We can also solve this with dense_rank function..',
#   'comment_author': 'Yogesh Kumar',
#   'comment_publishdate': '2022-11-13T11:02:33Z'},
#  {'comment_id': 'UgxwZS7_6AIh4BRtnw14AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Great exercice, here&#39;s my solution on SSMS :<br><br>With CTE as\r<br>\r<br>(select *, Max(Nbr)over(partition by DM)  as &#39;MAXIMUS&#39;\r<br>\tfrom\r<br>\t\t\t(select distinct date_modified\tas &#39;DM&#39;\r<br>\t\t\t\t\t, [FILE] as&#39;Fx&#39;\r<br>\t\t\t\t\t, count(id)over(partition by [File],date_modified ) as &#39;Nbr&#39;\r<br>\r<br>\t\t\tfrom\r<br>\t\t\t\t\t(select id\r<br>\t\t\t\t\t\t\t,date_modified\r<br>\t\t\t\t\t\t\t,right(file_name,len(file_name)-charindex(&#39;.&#39;,file_name)) as &#39;File&#39; \r<br>\t\t\t\t\tfrom files\r<br>\t\t\t\t\t)TB\r<br>\t\t\t)TB1)\r<br>select <a href="http://tb.dm/">TB.DM</a> as &#39;Date_modified&#39;, [File Extensions], MAXIMUS as &#39;Count&#39;\r<br>from\r<br>\t\t(select DM, string_agg(Fx,&#39;,&#39;) as &#39;File Extensions&#39;\r<br>\t\tfrom CTE\r<br>\t\tgroup by DM)TB\r<br>inner join (select distinct DM, Maximus from CTE)TB2 on TB.DM=<a href="http://tb2.dm/">TB2.DM</a>',
#   'comment_author': 'Yassir Nakkach',
#   'comment_publishdate': '2022-11-12T22:39:37Z'},
#  {'comment_id': 'UgwWJ_DHiJ3NgGdBG3F4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Amazing video thank you so much. Because of you I can easily solve medium level questions on stratascratch, data lemur etc...and hard questions too',
#   'comment_author': 'Shiv Sharma',
#   'comment_publishdate': '2022-11-11T22:38:36Z'},
#  {'comment_id': 'UgzoSRy5Qxd_LwEhL-Z4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'athlete  totalmedals \r<br>athlete1  8\r<br>athlete2  7\r<br>athlete3  7\r<br>athlete4  5\r<br>\r<br>output:\r<br>athlete   totalmedals  medal_diff\r<br>athlete1    8    0\r<br>athlete2    7    1\r<br>athlete3    7    1\r<br>athlete4    5   3<br><br>\rPlease give me an <br>answer above problem(compare max(medals) to another athlete',
#   'comment_author': 'Jeevan Reddy',
#   'comment_publishdate': '2022-11-11T06:49:51Z'},
#  {'comment_id': 'UgwaugCAs3-GlL2fRQd4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'String_agg function is not working , mine was Sql server 2016 version. which alternate function can I use to substitute this',
#   'comment_author': 'Aradhya Damera',
#   'comment_publishdate': '2022-11-10T11:38:59Z'},
#  {'comment_id': 'UgxmH8Y9ag5c3PjNgml4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Hi Taufiq, your explanation is just awesome, Please make video on query optimization',
#   'comment_author': 'Abhishek Gowda',
#   'comment_publishdate': '2022-11-07T11:46:30Z'},
#  {'comment_id': 'UgxTEYdm3LWo273dONF4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Thanks alot Taufiq. Below is my solution. I will look into your solution now and compare. Thanks again for sharing this.<br><br>with cte as (Select ID, Date_Modified, File_Name,SUBSTRING(file_name,INSTR(file_name,&#39;.&#39;)+1) as extension,<br>count(*) over (partition by Date_Modified,SUBSTRING(file_name,INSTR(file_name,&#39;.&#39;)+1) order by Date_Modified) as cn <br>from files)<br><br>select Date_Modified, GROUP_CONCAT(distinct extension order by extension desc) as extension, cn from cte where (Date_Modified,cn) in<br>(<br>Select Date_Modified,max(cn) from cte group by Date_Modified)<br>group by Date_Modified<br>order by Date_Modified asc',
#   'comment_author': 'Muhammad Fazlani',
#   'comment_publishdate': '2022-11-06T16:56:02Z'},
#  {'comment_id': 'UgwG2LKkyU1U-ucBCch4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'String aggregate function equivalent for mssql ?',
#   'comment_author': 'BR',
#   'comment_publishdate': '2022-11-06T02:39:41Z'},
#  {'comment_id': 'UgyOP3E58YDP6fOVrRR4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'For anyone looking for MySQL code. You can try this.<br><br>WITH A AS<br>(<br>SELECT <br>\tSUBSTRING_INDEX(file_name, &quot;.&quot;,-1) AS extension<br>    ,date_modified<br>    ,COUNT(date_modified) AS cnt<br>    ,DENSE_RANK() OVER(PARTITION BY date_modified ORDER BY COUNT(date_modified) DESC) AS rnk<br>FROM <br>\tfiles<br>GROUP BY <br>\tSUBSTRING_INDEX(file_name, &quot;.&quot;,-1)<br>    ,date_modified<br>ORDER BY <br>\tdate_modified<br>)<br><br>SELECT <br>\tdate_modified<br>\t,GROUP_CONCAT(extension ORDER BY extension DESC SEPARATOR &#39;,&#39;) AS extension<br>    ,MAX(cnt) AS cnt<br>FROM <br>\tA<br>WHERE <br>\trnk = 1<br>GROUP BY 1',
#   'comment_author': 'sr231yaj',
#   'comment_publishdate': '2022-11-05T11:03:13Z'},
#  {'comment_id': 'Ugw-53GH1yqiybtmNgN4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Hello Thoufiq,<br><br>Please let me know when your next live training will get started?',
#   'comment_author': 'Nikhila Vemuri',
#   'comment_publishdate': '2022-11-03T11:12:30Z'},
#  {'comment_id': 'UgylIRLMDSbSEB6O1Il4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Awsome video!!',
#   'comment_author': 'gonzalo alonso',
#   'comment_publishdate': '2022-11-03T04:09:58Z'},
#  {'comment_id': 'UgxKf8MP2UrIyfCgREt4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'select to_char(date_modified,&#39;YYYY-MM-DD&#39;)date_modified,listagg(extn,&#39;,&#39;) within group(order by extn desc)extension,extn_cnt count from(\r<br>select date_modified,extn,extn_cnt,dense_rank() over( partition by date_modified order by extn_cnt desc)rn from\r<br>(select date_modified,regexp_substr(file_name,&#39;\\.([a-z]+)$&#39;,1,1,&#39;i&#39;,1)extn,count(1)extn_cnt from FILE_MODIF_DATA\r<br>group by date_modified,regexp_substr(file_name,&#39;\\.([a-z]+)$&#39;,1,1,&#39;i&#39;,1)\r<br>)) where rn=1 group by to_char(date_modified,&#39;YYYY-MM-DD&#39;),extn_cnt;',
#   'comment_author': 'Sankar K',
#   'comment_publishdate': '2022-11-02T14:35:26Z'},
#  {'comment_id': 'UgwtWQ0AN8ozXVixOAd4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Hi Taufiq, could you please cover topics like debugging of complex queries and performance tuning',
#   'comment_author': 'MADHUSUDHAN HN',
#   'comment_publishdate': '2022-11-02T14:34:14Z'},
#  {'comment_id': 'Ugw4sHpnTwlMzTf1nLd4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Amazing  , thank you',
#   'comment_author': 'SAN',
#   'comment_publishdate': '2022-11-02T09:12:03Z'},
#  {'comment_id': 'Ugyxp9WrqZEtE3YPWzZ4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Great video sir,<br>Thanks a lot 🙏',
#   'comment_author': 'Avi',
#   'comment_publishdate': '2022-11-01T19:24:09Z'},
#  {'comment_id': 'Ugyo-oQ04atHoUCv7Nt4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Port to Oracle<br>create table files<br>(<br>id\xa0 \xa0 \xa0 \xa0 \xa0 \xa0 \xa0 int primary key,<br>date_modified \xa0 date,<br>file_name \xa0 \xa0 \xa0 varchar2(50)<br>);<br><br>insert into files values (1\xa0 \xa0 , \xa0 to_date(&#39;2021-06-03&#39;,&#39;yyyy-mm-dd&#39;), &#39;thresholds.svg&#39;);<br>insert into files values (2\xa0 \xa0 , \xa0 to_date(&#39;2021-06-01&#39;,&#39;yyyy-mm-dd&#39;), &#39;redrag.py&#39;);<br>insert into files values (3\xa0 \xa0 , \xa0 to_date(&#39;2021-06-03&#39;,&#39;yyyy-mm-dd&#39;), &#39;counter.pdf&#39;);<br>insert into files values (4\xa0 \xa0 , \xa0 to_date(&#39;2021-06-06&#39;,&#39;yyyy-mm-dd&#39;), &#39;reinfusion.py&#39;);<br>insert into files values (5\xa0 \xa0 , \xa0 to_date(&#39;2021-06-06&#39;,&#39;yyyy-mm-dd&#39;), &#39;tonoplast.docx&#39;);<br>insert into files values (6\xa0 \xa0 , \xa0 to_date(&#39;2021-06-01&#39;,&#39;yyyy-mm-dd&#39;), &#39;uranian.pptx&#39;);<br>insert into files values (7\xa0 \xa0 , \xa0 to_date(&#39;2021-06-03&#39;,&#39;yyyy-mm-dd&#39;), &#39;discuss.pdf&#39;);<br>insert into files values (8\xa0 \xa0 , \xa0 to_date(&#39;2021-06-06&#39;,&#39;yyyy-mm-dd&#39;), &#39;nontheologically.pdf&#39;);<br>insert into files values (9\xa0 \xa0 , \xa0 to_date(&#39;2021-06-01&#39;,&#39;yyyy-mm-dd&#39;), &#39;skiagrams.py&#39;);<br>insert into files values (10, \xa0 to_date(&#39;2021-06-04&#39;,&#39;yyyy-mm-dd&#39;), &#39;flavors.py&#39;);<br>insert into files values (11, \xa0 to_date(&#39;2021-06-05&#39;,&#39;yyyy-mm-dd&#39;), &#39;nonv.pptx&#39;);<br>insert into files values (12, \xa0 to_date(&#39;2021-06-01&#39;,&#39;yyyy-mm-dd&#39;), &#39;under.pptx&#39;);<br>insert into files values (13, \xa0 to_date(&#39;2021-06-02&#39;,&#39;yyyy-mm-dd&#39;), &#39;demit.csv&#39;);<br>insert into files values (14, \xa0 to_date(&#39;2021-06-02&#39;,&#39;yyyy-mm-dd&#39;), &#39;trailings.pptx&#39;);<br>insert into files values (15, \xa0 to_date(&#39;2021-06-04&#39;,&#39;yyyy-mm-dd&#39;), &#39;asst.py&#39;);<br>insert into files values (16, \xa0 to_date(&#39;2021-06-03&#39;,&#39;yyyy-mm-dd&#39;), &#39;pseudo.pdf&#39;);<br>insert into files values (17, \xa0 to_date(&#39;2021-06-03&#39;,&#39;yyyy-mm-dd&#39;), &#39;unguarded.jpeg&#39;);<br>insert into files values (18, \xa0 to_date(&#39;2021-06-06&#39;,&#39;yyyy-mm-dd&#39;), &#39;suzy.docx&#39;);<br>insert into files values (19, \xa0 to_date(&#39;2021-06-06&#39;,&#39;yyyy-mm-dd&#39;), &#39;anitsplentic.py&#39;);<br>insert into files values (20, \xa0 to_date(&#39;2021-06-03&#39;,&#39;yyyy-mm-dd&#39;), &#39;tallies.py&#39;);<br><br>with cte as<br>\xa0\xa0\xa0\xa0(select date_modified,<br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0regexp_substr(file_name, &#39;\\w+$&#39;) as file_ext,<br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0count(*) as cnt<br>\xa0\xa0\xa0\xa0\xa0from files<br>\xa0\xa0\xa0\xa0\xa0group by date_modified,<br>\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0\xa0regexp_substr(file_name, &#39;\\w+$&#39;)<br>\xa0\xa0\xa0\xa0)<br>\xa0\xa0\xa0\xa0select date_modified,<br>\xa0\xa0\xa0\xa0\xa0listagg(file_ext, &#39;,&#39;) within group (order by file_ext desc) as extension,<br>\xa0\xa0\xa0\xa0\xa0max(cnt) as the_count<br>\xa0\xa0\xa0from cte c1<br>\xa0\xa0\xa0where cnt = (select max(cnt) from cte c2 where c1.date_modified=c2.date_modified )<br>\xa0\xa0\xa0group by date_modified<br>\xa0\xa0order by 1;',
#   'comment_author': 'Paul  Hartman',
#   'comment_publishdate': '2022-11-01T16:32:46Z'},
#  {'comment_id': 'UgyzBbRb-mlPJoh0OyZ4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'good explanation',
#   'comment_author': 'Anuj Shah',
#   'comment_publishdate': '2022-11-01T15:33:21Z'},
#  {'comment_id': 'UgzjlOvvD9nm_ad0LKp4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'your contents are very useful, Thanks for it, please do on  performance &amp; Tuning......',
#   'comment_author': 'dev kilari',
#   'comment_publishdate': '2022-11-01T12:17:57Z'},
#  {'comment_id': 'Ugwbr77Sl1xOJwremeh4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': '@techtfq, could you please share your email id. I have a problem statement and solution also. But eager to see the way you solve it. I got the result but I know you will have the most efficient solution..',
#   'comment_author': 'vp',
#   'comment_publishdate': '2022-11-01T10:03:42Z'},
#  {'comment_id': 'Ugz6lo-buFbs5llfQQp4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'MySQL  solution:<br><br>with cte as<br>(select date_modified, substr(file_name, position(&quot;.&quot; in file_name)+1) extersion, count(*) ct<br>from files <br>group by date_modified, extersion)<br>, cte2 as <br>(select *, rank() over (partition by date_modified order by ct desc) rk<br>from cte)<br>select date_modified, group_concat(extersion order by extersion desc) extension, max(ct) ct<br> from cte2<br>where rk = 1<br>group by date_modified<br>;',
#   'comment_author': 'Data Engineering Studies',
#   'comment_publishdate': '2022-11-01T09:00:11Z'},
#  {'comment_id': 'Ugz76Uf_8oeS20dAmYN4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'WITH TAB_1 AS(<br>SELECT <br>date_modified, <br>SUBSTRING_INDEX(file_name,&#39;.&#39;,-1) AS ext,<br>COUNT(*) AS cnt<br>FROM practise.files <br>GROUP BY date_modified,SUBSTRING_INDEX(file_name,&#39;.&#39;,-1)<br>),<br>TAB_2 AS<br> (SELECT *, MAX(cnt) OVER(PARTITION BY date_modified) AS max_cnt FROM TAB_1 )<br> <br>SELECT date_modified, <br>              group_concat(ext ORDER BY ext DESC) AS files, <br>              MAX(cnt) AS cnt<br>FROM TAB_2 <br>WHERE cnt=max_cnt <br>GROUP BY date_modified',
#   'comment_author': 'pankaj negi',
#   'comment_publishdate': '2022-11-01T08:45:23Z'},
#  {'comment_id': 'Ugw1VYqeRQfpe9NwFxN4AaABAg',
#   'video_id': 'Det4ZjBSe3M',
#   'comment_text': 'Urs explanation really appreciate',
#   'comment_author': 'Ramesh Sanipaya vlogs',
#   'comment_publishdate': '2022-11-01T05:11:53Z'},
#  {'comment_id': 'UgzK9jhqUwOzW70vB5F4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'nicely explained',
#   'comment_author': 'Pravin M',
#   'comment_publishdate': '2023-11-09T02:15:22Z'},
#  {'comment_id': 'UgyBKK7tV8-dOambHMB4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'Wow, wonderful! Thank you so much, extremely clear and deep explanation of the different JOINS. Thanx! :D',
#   'comment_author': 'Jola',
#   'comment_publishdate': '2023-11-08T15:14:29Z'},
#  {'comment_id': 'UgyZkAqVm48-UUM8PHd4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'Very simply way and with proper examples, joins are are explained here.Thanks for sharing.',
#   'comment_author': 'Sunil kumar K M',
#   'comment_publishdate': '2023-11-04T11:06:58Z'},
#  {'comment_id': 'UgziSiiIZFaPVYNL_QF4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'Best ever explanation I came across, on joins.',
#   'comment_author': 'BRK Prasad',
#   'comment_publishdate': '2023-10-31T10:51:06Z'},
#  {'comment_id': 'UgzdPJ5AtqRZy8qRboh4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'Very very very very helpfull for me, Really thank you so much for the interview purposes.....',
#   'comment_author': 'Hari Komatapalli',
#   'comment_publishdate': '2023-10-30T06:49:37Z'},
#  {'comment_id': 'Ugy_Z8xp8LFmCc-PcUl4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'Excellent job 👏 👍',
#   'comment_author': 'Anwar Khan',
#   'comment_publishdate': '2023-10-29T11:39:31Z'},
#  {'comment_id': 'UgxUyuyV5lABdPisLuZ4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'Thanks a lot!',
#   'comment_author': 'Harshitha B',
#   'comment_publishdate': '2023-10-29T07:34:02Z'},
#  {'comment_id': 'Ugx6DwE7N-l7-uFJCgJ4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'found a Gem🌼🌸❤',
#   'comment_author': 'U.P.N',
#   'comment_publishdate': '2023-10-26T03:42:43Z'},
#  {'comment_id': 'UgypftMYpFI7txpn66R4AaABAg',
#   'video_id': 'xUsY2jWQa1w',
#   'comment_text': 'You have explained SQL JOIN extremely well in details, thumbs up with thanks.',
#   'comment_author': 'Clementi Hammock',
#   'comment_publishdate': '2023-10-21T17:42:19Z'},
#  ...]

# %%
#Now to get the playlist detials 
def get_playlist_details(channel_ids):
    next_page_token = None
    playlist = []
    playlistdetails_request = youtube_call.playlists().list(
        part = "id,contentDetails,snippet",
        channelId = channel_ids,
        maxResults = 50,
        pageToken = next_page_token
    )
    playlistdetials_response = playlistdetails_request.execute()

    while True:
        for i in playlistdetials_response["items"]:
            playlist_data = {
                "playlist_id" : i["id"],
                "channel_id" : i["snippet"]["channelId"],
                "playlist_name" : i["snippet"]["title"]
            }
            playlist.append(playlist_data)
            
        next_page_token = playlistdetials_response.get("nextPageToken")    
        if next_page_token == None:
            break    
    return playlist

# %%
playlist_details_call = get_playlist_details("UCykSoHEAMVSU_w6ACWlxlzA")

# %%
playlist_details_call
# Out:
# [{'playlist_id': 'PLomWanZL-pO98qrLJY5tjcYvaun3dQ6SM',
#   'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#   'playlist_name': 'Industry Use Cases'},
#  {'playlist_id': 'PLomWanZL-pO9m48ZlPL4AdTcw4dtT0VOx',
#   'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#   'playlist_name': 'Amazon Web Services'},
#  {'playlist_id': 'PLomWanZL-pO-pOW7rCuqqC5bnc8AtXN2g',
#   'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#   'playlist_name': 'Docker'},
#  {'playlist_id': 'PLomWanZL-pO_OUdHBGKYIxTX8lApB_dDB',
#   'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#   'playlist_name': 'Kubernetes'},
#  {'playlist_id': 'PLomWanZL-pO_q-OXqFzYVlAHnqw_3JgZX',
#   'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#   'playlist_name': 'Terraform'},
#  {'playlist_id': 'PLomWanZL-pO8ylOY-ALCkueylmdxfF2_c',
#   'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#   'playlist_name': 'Azure Cloud'},
#  {'playlist_id': 'PLomWanZL-pO9M7X05s4msbJ15_GxRqivV',
#   'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#   'playlist_name': 'Google Cloud Platform'},
#  {'playlist_id': 'PLomWanZL-pO9KSO8UnZo0eFxDWc61GY_5',
#   'channel_id': 'UCykSoHEAMVSU_w6ACWlxlzA',
#   'playlist_name': 'DevOps Training'}]

# %%
len(playlist_details_call)
# Out:
# 8

# %%
client = pymongo.MongoClient("mongodb+srv://Nivetha:mongonivetha123@cluster0.adch71s.mongodb.net/?retryWrites=true&w=majority")
db = client["youtube_data"]

# %%
client = MongoClient("mongodb+srv://Nivetha:mongonivetha123@cluster0.adch71s.mongodb.net/?retryWrites=true&w=majority", server_api=ServerApi('1'))
client.admin.command('ping')
# Out:
# {'ok': 1}

# %%
col = db["sample"]
s = {"name" :"xxx","year":2000,"age":23}
col.insert_one(s)
# Out:
# InsertOneResult(ObjectId('655452fdd89873834a65139a'), acknowledged=True)

# %%
'''Creating a function called channel details and assigning all the functions created to get 
chennal details,playlist details , video details and comment details'''

def channel_details(channel_id):
    channel_detail = get_channel_details(channel_id)
    playlist_details = get_playlist_details(channel_id)
    video_ids= get_video_ids(channel_id)
    video_details = get_video_details(video_ids)
    comment_details = get_comment_details(video_ids)

    col1 = db["channel_details"]
    col1.insert_one({"Channel_information" :channel_detail, "playlist_information" :playlist_details,
                      "Video_ids_information" : video_ids,"video_information" : video_details , "comment_information":comment_details })
    return  print("Insertion completed successfully")

# %%
channel1_insertion = channel_details("UC6RTJC0JgdVn_CCJe23tf6w")   #The Data Dude Youtube Channel

# %%
channel2_insertion = channel_details("UCnz-ZXXER4jOvuED5trXfEA")   #techTFQ youtube channel
# Out:
# Insertion completed successfully

# %%
channel3_insertion = channel_details("UC5--wS0Ljbin1TjWQX6eafA")   #bigboxswe code for fun channel
# Out:
# Insertion completed successfully

# %%
channel4_insertion = channel_details("UCfrvq9ybG1PxWulbSpvxCxA")   #bommaniac channel
# Out:
# Insertion completed successfully

# %%
channel5_insertion = channel_details("UCykSoHEAMVSU_w6ACWlxlzA")   #octobit8 channel
# Out:
# Insertion completed successfully

# %%
for i in col1.find():
    pprint(i["Channel_information"]["channel_id"])
# Out:
# 'UC6RTJC0JgdVn_CCJe23tf6w'
# 'UCnz-ZXXER4jOvuED5trXfEA'
# 'UC5--wS0Ljbin1TjWQX6eafA'
# 'UCfrvq9ybG1PxWulbSpvxCxA'
# 'UCykSoHEAMVSU_w6ACWlxlzA'

# %%
len(i)
# Out:
# 6

# %%
    #Creating table for channel,playlist ,video, and comment details
def channels_table(): 
        mydb = mysql.connect(
            host = "localhost",
            user = "root",
            password = "mysql",
            database = "youtube_data",
            port = "3306"
        )

        cursor = mydb.cursor()

        drop_query = '''drop table if exists channels'''
        cursor.execute(drop_query)
        mydb.commit()
        
        #creating a table named channels
        try:
            channel_table ='''create table if not exists channels(channel_title varchar(100),channel_id varchar(70) primary key,
                            channel_subscribers bigint,channel_viewcount bigint, channel_videocount int,channel_description text)'''

            cursor.execute(channel_table)               
            mydb.commit()

        except:
            print("Channel table already created")  

        ch_list = []
        db = client["youtube_data"]   
        col1 = db["channel_details"]
        for i in col1.find({},{"_id":0,"Channel_information":1}):
            ch_list.append(i["Channel_information"])
        df = pd.DataFrame(ch_list)       
        
        #inserting the values of channels dataframe into the channels table
        for index,rows in df.iterrows():
            insert_query = '''insert into channels(channel_title,
                                                channel_id,
                                                channel_subscribers,
                                                channel_viewcount,
                                                channel_videocount,
                                                channel_description) 
                                                
                                                values(%s,%s,%s,%s,%s,%s)'''
            values = (rows["channel_title"],
                    rows["channel_id"],
                    rows["channel_subscribers"],
                    rows["channel_viewcount"],
                    rows["channel_videocount"],
                    rows["channel_description"])    

            try:
                cursor.execute(insert_query,values)
                mydb.commit()
            except:
                print("Channel values already inserted")

# %%
#Creating table for playlist details

def playlist_table():
    mydb = mysql.connect(
        host = "localhost", 
        user = "root",
        password = "mysql",
        database = "youtube_data",
        port = "3306"
    )

    cursor = mydb.cursor()

    drop_query = '''drop table if exists playlists'''
    cursor.execute(drop_query)
    mydb.commit()
    
    #creating a table named playlists
    playlist_query ='''create table if not exists playlists(playlist_id varchar(100) primary key,channel_id varchar(70),
                                                                playlist_name text)'''

    cursor.execute(playlist_query)               
    mydb.commit()

    pl_list = []
    db = client["youtube_data"]   
    col1 = db["channel_details"]
    for i in col1.find({},{"_id":0,"playlist_information":1}):
        for j in range(len(i["playlist_information"])):
            pl_list.append(i["playlist_information"][j])
    df_playlist = pd.DataFrame(pl_list)  

    #inserting the values of playlist dataframe into the playlists table
    for index,rows in df_playlist.iterrows():
        insert_query = '''insert into playlists(playlist_id,channel_id,playlist_name)
                                            
                                            values(%s,%s,%s)'''
        values = (rows["playlist_id"],
                rows["channel_id"],
                rows["playlist_name"]
                )    

        cursor.execute(insert_query,values)
        mydb.commit()

# %%
#creating table for video details
def video_table():
    mydb = mysql.connect(
            host = "localhost", 
            user = "root",
            password = "mysql",
            database = "youtube_data",
            port = "3306"
        )

    cursor = mydb.cursor()

    drop_query = '''drop table if exists videos'''
    cursor.execute(drop_query)
    mydb.commit()

    #for creating a table named videos
    video_query ='''create table if not exists videos(channel_title varchar(50),channel_id varchar(70),video_title varchar(100),
                                        video_id varchar(50) primary key,video_thumnails varchar(200),
                                        video_publishDate timestamp,video_duration time,
                                        video_view bigint,video_likes bigint,video_favorite int,
                                        video_comments bigint,video_captionStatus varchar(20))'''

    cursor.execute(video_query)               
    mydb.commit()

    vd_list = []
    db = client["youtube_data"]   
    col1 = db["channel_details"]
    for i in col1.find({},{"_id":0,"video_information":1}):
        for j in range(len(i["video_information"])):
            vd_list.append(i["video_information"][j])
    df_video = pd.DataFrame(vd_list)  

    cursor = mydb.cursor()
    
    #inserting the values of video dataframe into videos table
    for index,rows in df_video.iterrows():
        insert_query = '''insert into videos(channel_title,channel_id,video_title,video_id,video_thumnails,video_publishDate,
                                video_duration,video_view,video_likes,video_favorite,video_comments,video_captionStatus)
                                            
                                            values(%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s,%s)'''

        # Convert the string value to datetime object                                    
        dt = datetime.datetime.strptime(rows["video_publishDate"], "%Y-%m-%dT%H:%M:%SZ")
        # Format the datetime object to match MySQL timestamp format
        dt_formatted = dt.strftime("%Y-%m-%d %H:%M:%S")
        
        # Parse the string value to a timedelta object
        duration = isodate.parse_duration(rows["video_duration"])

        # Convert the timedelta object to a time object
        duration = (datetime.datetime.min + duration).time()

        values = (rows["channel_title"],
                rows["channel_id"],
                rows["video_title"],
                rows["video_id"],
                rows["video_thumnails"],
                dt_formatted,
                duration,
                rows["video_view"],
                rows["video_likes"],
                rows["video_favorite"],
                rows["video_comments"],
                rows["video_captionStatus"]
                )    

        cursor.execute(insert_query,values)
        mydb.commit()

# %%
#creating table for comment details
def comments_table():
    mydb = mysql.connect(
            host = "localhost", 
            user = "root",
            password = "mysql",
            database = "youtube_data",
            port = "3306"
        )

    cursor = mydb.cursor()

    drop_query = '''drop table if exists comments'''
    cursor.execute(drop_query)
    mydb.commit()
    #for creating a table named comments
    comment_query ='''create table if not exists comments(comment_id varchar(100) primary key,video_id varchar(70),comment_text text,
                                                            comment_author varchar(100),comment_publishdate timestamp)'''

    cursor.execute(comment_query)               
    mydb.commit()

    cmt_list = []
    db = client["youtube_data"]   
    col1 = db["channel_details"]
    for i in col1.find({},{"_id":0,"comment_information":1}):
        for j in range(len(i["comment_information"])):
            cmt_list.append(i["comment_information"][j])
    df_comment = pd.DataFrame(cmt_list)  

    #inserting the values of dataframe into the comments table
    for index,rows in df_comment.iterrows():
            insert_query = '''insert into comments(comment_id,video_id,comment_text,comment_author,comment_publishdate)
                                                
                                                values(%s,%s,%s,%s,%s)'''

            # Convert the string value to datetime object                                    
            dt = datetime.datetime.strptime(rows["comment_publishdate"], "%Y-%m-%dT%H:%M:%SZ")
            # Format the datetime object to match MySQL timestamp format
            dt_formatted = dt.strftime("%Y-%m-%d %H:%M:%S")

            values = (rows['comment_id'],
                    rows['video_id'],
                    rows['comment_text'],
                    rows['comment_author'],
                    dt_formatted
                    )    

            cursor.execute(insert_query,values)
            mydb.commit()

# %%
def tables():
    channels_table()
    playlist_table()
    video_table()
    comments_table()

    return "Table created successfully"

# %%
tables_call =tables()

# %%
tables_call
# Out:
# 'Table created successfully'

# %%
#creating a dataframe using streamlit
def show_channel_table():
    ch_list = []
    db = client["youtube_data"]   
    col1 = db["channel_details"]
    for i in col1.find({},{"_id":0,"Channel_information":1}):
        ch_list.append(i["Channel_information"])
    dfst_channel= st.dataframe(ch_list)  

    return dfst_channel

# %%
dfst_channel
# Out:
# DeltaGenerator()

# %%
#creating streamlit dataframe for playlist table
def show_playlist_table():
    pl_list = []
    db = client["youtube_data"]   
    col1 = db["channel_details"]
    for i in col1.find({},{"_id":0,"playlist_information":1}):
        for j in range(len(i["playlist_information"])):
            pl_list.append(i["playlist_information"][j])
    dfst_playlist = st.dataframe(pl_list)  

    return dfst_playlist

# %%
#creating streamlit dataframe for videos table
def show_video_table():
    vd_list = []
    db = client["youtube_data"]   
    col1 = db["channel_details"]
    for i in col1.find({},{"_id":0,"video_information":1}):
        for j in range(len(i["video_information"])):
            vd_list.append(i["video_information"][j])
    dfst_video = st.dataframe(vd_list)  

    return dfst_video

# %%
#creating streamlit dataframe for comments table
def show_comment_table(): 
    cmt_list = []
    db = client["youtube_data"]   
    col1 = db["channel_details"]
    for i in col1.find({},{"_id":0,"comment_information":1}):
        for j in range(len(i["comment_information"])):
            cmt_list.append(i["comment_information"][j])
    dfst_comment = st.dataframe(cmt_list)  

    return dfst_comment

# %%
#Streamlit part
st.title(":red[YOUTUBE DATA HARVESTING AND WAREHOUSING USING SQL, MongoDB AND STREAMLIT]")
st.header("Hello!")

channel_id = st.text_input("Enter the Channel ID:")

if st.button("Collect and store the data"):
    ch_ids =[]
    db =client["youtube_data"]
    col1 = db["channel_details"]
    for i in col1.find({},{"_id":0,"Channel_information":1}):
        ch_ids.append(i["Channel_information"]["channel_id"])

    if channel_id in ch_ids:
        st.success("Channel Details of the given channel ID is already exists")      

    else:
        st.success("[IPB]Entering channel details")
        insert = channel_details(channel_id)   
        st.success(insert) 

    if st.button("Push data into MySql"):
        table_creation = tables()
        st.success(table_creation)

    view_table = st.radio("SELECTED THE REQUIRED TABLE",("CHANNELS","PLAYLISTS","VIDEOS","COMMENTS"))  

    if view_table == "CHANNELS":
        show_channel_table()
    elif view_table == "PLAYLISTS":
        show_playlist_table()
    elif view_table == "VIDEOS":
        show_video_table()
    elif view_table == "COMMENTS":
        show_comment_table()

# %%
ch_ids =[]
db =client["youtubr_data"]
col1 = db["channel_details"]
for i in col1.find({},{"_id":0,"Channel_information":1}):
    ch_ids.append(i["Channel_information"]["channel_id"])

# %%
ch_ids
# Out:
# ['UC6RTJC0JgdVn_CCJe23tf6w', 'UCn1O_4_ApzbYwrsUdRoMmOg']

# %%
#Question Part
mydb = mysql.connect(
        host = "localhost", 
        user = "root",
        password = "mysql",
        database = "youtube_data",
        port = "3306"
    )

cursor = mydb.cursor()

questions = st.selectbox("Select you question here",("1.What are the names of all videos and its corresponding channels?",
          "2.Which channels have the most number of videos and its count?",
          "3.What are the top most viewed videos and their repective channels",
          "4.How many comments were on each video and what are their corresponding video names",
          "5.Which videos have highest likes and name its corresponding channel names?",
          "6.What is the total number of likes  for each video and what are their corresponding video names?",
          "7.What is the total number of views for each channel,and what are their channel name?",
          "8.What are the names of all the channels that have published videos in the year 2022",
          "9.What is the average duration of all videos in each channel, and what are their channel names?",
          "10.Which videos have the highest number of comments and what are their corresponding channel names?"))

#question 1
mydb = mysql.connect(
            host = "localhost",
            user = "root",
            password = "mysql",
            database = "youtube_data",
            port = "3306",
          #  consume_results = True
        )
cursor = mydb.cursor()
if questions=="1.What are the names of all videos and its corresponding channels?": 
    query1 = '''select video_title as video_name,channel_title as channel_name from videos'''
    cursor.execute(query1)
    t1 = cursor.fetchall()
    mydb.commit()
    df1 =pd.DataFrame(t1,columns=["video name","channel name"])
    st.write(df1)

#Question 2
elif questions=="2.Which channels have the most number of videos and its count?": 
  query2 = '''select channel_title as channel_name, channel_videocount as no_of_videos from channels order by channel_videocount desc'''
  cursor.execute(query2)
  t2 = cursor.fetchall()
  mydb.commit()
  df2 =pd.DataFrame(t2,columns=["channel name","Number of videos"])
  st.write(df2)

#Question 3
elif questions=="3.What are the top most viewed videos and their repective channels": 
  query3 = '''select channel_title as channel_name,video_title as video_name,video_view as view_count from videos 
                where video_view is not null order by video_view desc limit 10 '''
  cursor.execute(query3)
  t3 = cursor.fetchall()
  mydb.commit()
  df3 =pd.DataFrame(t3,columns=["channel name","video name","video views"])
  st.write(df3)      
  
#Question 4
elif questions=="3.What are the top most viewed videos and their repective channels": 
  query4 = '''select video_title as video_name,video_comments as comment_count from videos where video_comments is not null'''
  cursor.execute(query4)
  t4 = cursor.fetchall()
  mydb.commit()
  df4 =pd.DataFrame(t4,columns=["video name","Number of comments"])
  st.write(df4)      

#Question 5
elif questions=="5.Which videos have highest likes and name its corresponding channel names?": 
  query5 = '''select video_title as video_name,video_likes as likes_count from videos where video_likes is not null order by video_likes desc'''
  cursor.execute(query5)
  t5 = cursor.fetchall()
  mydb.commit()
  df5 =pd.DataFrame(t5,columns=["video name","likes count"])
  st.write(df5)  

#Question 6
elif questions=="6.What is the total number of likes  for each video and what are their corresponding video names?": 
  query6 = '''select video_title as video_name,video_likes as likes_count from videos'''
  cursor.execute(query6)
  t6 = cursor.fetchall()
  mydb.commit()
  df6 =pd.DataFrame(t6,columns=["video name","likes count"])
  st.write(df6)  

#Question 7
elif questions=="7.What is the total number of views for each channel,and what are their channel name?": 
  query7 = '''select channel_title as channel_name,channel_viewcount as channel_views from channels'''
  cursor.execute(query7)
  t7 = cursor.fetchall()
  mydb.commit()
  df7 =pd.DataFrame(t7,columns=["channel name","views count"])
  st.write(df7)  
 
#Question 8
elif questions=="8.What are the names of all the channels that have published videos in the year 2022": 
  query8 = '''select channel_title as channel_name,video_title as video_name,video_publishDate as video_releasedate from videos
                        where extract(year from video_publishDate)=2022'''
  cursor.execute(query8)
  t8 = cursor.fetchall()
  mydb.commit()
  df8 =pd.DataFrame(t8,columns=["channel name","video name","video published date"])
  st.write(df8)  

#Question 9
elif questions=="9.What is the average duration of all videos in each channel, and what are their channel names?": 
  query9 = '''select channel_title as channel_name,AVG(video_duration) as average_duration from videos group by channel_title'''
  cursor.execute(query9)
  t9 = cursor.fetchall()
  mydb.commit()
  df9 =pd.DataFrame(t9,columns=["channel name","average duration"])
  st.write(df9)

#Question 10
elif questions=="10.Which videos have the highest number of comments and what are their corresponding channel names?": 
  query10 = '''select channel_title as channel_name,video_title as video_name,video_comments as comments_count from videos
                        where video_comments is not null order by video_comments desc'''
  cursor.execute(query10)
  t10 = cursor.fetchall()
  mydb.commit()
  df10 =pd.DataFrame(t10,columns=["channel name","video name","Numbers of comments"])
  #df10
  st.write(df10)

# %%
#question 7
mydb = mysql.connect(
            host = "localhost",
            user = "root",
            password = "mysql",
            database = "youtube_data",
            port = "3306",
          #  consume_results = True
        )
cursor = mydb.cursor()
if questions=="7.What is the total number of views for each channel,and what are their channel name?": 
  query7 = '''select channel_title as channel_name,channel_viewcount as channel_views from channels'''
  cursor.execute(query7)
  t7 = cursor.fetchall()
  mydb.commit()
  df7 =pd.DataFrame(t7,columns=["channel name","views count"])
  st.write(df7)

# %%
#question 8
mydb = mysql.connect(
            host = "localhost",
            user = "root",
            password = "mysql",
            database = "youtube_data",
            port = "3306",
          #  consume_results = True
        )
cursor = mydb.cursor()
if questions=="8.What are the names of all the channels that have published videos in the year 2022": 
  query8 = '''select channel_title as channel_name,video_title as video_name,video_publishDate as video_releasedate from videos
                        where extract(year from video_publishDate)=2022'''
  cursor.execute(query8)
  t8 = cursor.fetchall()
  mydb.commit()
  df8 =pd.DataFrame(t8,columns=["channel name","video name","video published date"])
  st.write(df8)

# %%
#question 9
mydb = mysql.connect(
            host = "localhost",
            user = "root",
            password = "mysql",
            database = "youtube_data",
            port = "3306",
          #  consume_results = True
        )
cursor = mydb.cursor()
if questions=="9.What is the average duration of all videos in each channel, and what are their channel names?": 
  query9 = '''select channel_title as channel_name,AVG(video_duration) as average_duration from videos group by channel_title'''
  cursor.execute(query9)
  t9 = cursor.fetchall()
  mydb.commit()
  df9 =pd.DataFrame(t9,columns=["channel name","average duration"])
  #df9
  st.write(df9)

# %%
mydb = mysql.connect(
            host = "localhost",
            user = "root",
            password = "mysql",
            database = "youtube_data",
            port = "3306",
          #  consume_results = True
        )
cursor = mydb.cursor()
if questions=="10.Which videos have the highest number of comments and what are their corresponding channel names?": 
  query10 = '''select channel_title as channel_name,video_title as video_name,video_comments as comments_count from videos
                        where video_comments is not null order by video_comments desc'''
  cursor.execute(query10)
  t10 = cursor.fetchall()
  mydb.commit()
  df10 =pd.DataFrame(t10,columns=["channel name","video name","Numbers of comments"])
  #df10
  st.write(df10)
# Out:
#     channel name                                         video name  \
# 0      bigboxSWE                          Stop Studying Programming
# 1        techTFQ  SQL Window Function | How to write SQL Query u...
# 2      bigboxSWE             How To Replace Video Games With Coding
# 3        techTFQ  Learn how to write SQL Queries(Practice Comple...
# 4        techTFQ  How to get your 1st DATA ANALYST Job | Data An...
# ..           ...                                                ...
# 285     bomaniac  The BEST communication tip I know of #communic...
# 286     bomaniac  Amazing book: Dotcom secrets #sales #marketing...
# 287     bomaniac  I was not interested in relationships #relatio...
# 288     bomaniac  The number one best topic for a speech #selfim...
# 289     bomaniac                      Get a weighted sleeping mask!
#
#      Numbers of comments
# 0                   1558
# 1                   1238
# 2                   1094
# 3                   1056
# 4                   1042
# ..                   ...
# 285                    0
# 286                    0
# 287                    0
# 288                    0
# 289                    0
#
# [290 rows x 3 columns]
